# %%
# Please execute/shift-return this cell everytime you run the notebook.  Don't edit it. 
# %load_ext autoreload
# %autoreload 2
from notebook import *
# Out:
# <style>h1 {font-size: 2vw;} h2 {font-size: 1.5vw;} p {font-size: 1.4vw;} div.prompt, code, output, prompt, kbd, pre, samp {font-family: 'SF Mono', 'Courier New', Courier, monospace, sans-serif !important;font-size: 1.4vw !important;}</style>

# %% [markdown]
#  # Cache Simulation -- 2-way

# %% [markdown]
# What if we have a 2-way, 16-byte blocked, 16-block cache?

# %%
df = pd.read_csv("addresses.csv",skipfooter=1,engine='python')
df["address"] = df["address"].str.replace('0x','')
df["address"]=df[["address"]].apply(lambda x: x.astype(str).map(lambda x: int(x, base=16)))
# only show the first N addresses 
#N = 32
#df2 = df2.iloc[:N]
block_size = 16
offset_bits = int(math.log2(block_size))
number_of_blocks = 16
way_assoc=2
number_of_sets = number_of_blocks/way_assoc
index_bits = int(math.log2(number_of_sets))
df["tag"]=(df["address"].apply(lambda x: x >> (offset_bits+index_bits)))
df["tag"] = df["tag"].apply(lambda x: hex(x))
df["index"] = df["address"].apply(lambda x: hex((x>>offset_bits) % number_of_blocks))
df["address"] = df["address"].apply(lambda x: hex(x))
display_df_mono(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv("addresses.csv",skipfooter=1,engine='python')
#       2 df["address"] = df["address"].str.replace('0x','')
#       3 df["address"]=df[["address"]].apply(lambda x: x.astype(str).map(lambda x: int(x, base=16)))
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## Cache performance of code on "real machines"
#
# ### NVIDIA Jetson Nano -- Tegra X1

# %%
render_code("4way_madd/madd.c", show=["//START","//END"])
# Out:
# // 4way_madd/madd.c:55-67 (13 lines)
#     //START
#     for(i = 0; i < RUN_ARRAY_SIZE; i++)
#     {
#         e[i] = (a[i] * b[i] + c[i])/d[i];
# #ifdef DUMP
#         fprintf(stderr, "a[%d], %p\n",i,&a[i]);
#         fprintf(stderr, "b[%d], %p\n",i,&b[i]);
#         fprintf(stderr, "c[%d], %p\n",i,&c[i]);
#         fprintf(stderr, "d[%d], %p\n",i,&d[i]);
#         fprintf(stderr, "e[%d], %p\n",i,&e[i]);
# #endif
#     }
#   //END

# %% [markdown]
# Let's run it without the above loop code to figure the baseline memory accesses without running the loop on a Jetson nano.
#
# #### Run without the 4-way matrix add loop code.

# %%
# Run it "without" the above code.
! ssh htseng@nano-2 "lscpu; cd courses/CSE142/demo/memory/4way_madd/; make clean madd_nano; valgrind --tool=cachegrind ./madd_nano 16384 0 "
# Out:
# Architecture:        aarch64
# Byte Order:          Little Endian
# CPU(s):              4
# On-line CPU(s) list: 0-3
# Thread(s) per core:  1
# Core(s) per socket:  4
# Socket(s):           1
# Vendor ID:           ARM
# Model:               1
# Model name:          Cortex-A57
# Stepping:            r1p1
# CPU max MHz:         1479.0000
# CPU min MHz:         102.0000
# BogoMIPS:            38.40
# L1d cache:           32K
# L1i cache:           48K
# L2 cache:            2048K
# Flags:               fp asimd evtstrm aes pmull sha1 sha2 crc32
# rm -f madd_intel madd_nano *_O3 *~ madd_A_fission cachegrind* *.perf madd_dump
# cc -O1 -DHAVE_LINUX_PERF_EVENT_H -g  -DNANO perfstats.c madd.c -o madd_nano
# ==15683== Cachegrind, a cache and branch-prediction profiler
# ==15683== Copyright (C) 2002-2017, and GNU GPL'd, by Nicholas Nethercote et al.
# ==15683== Using Valgrind-3.13.0 and LibVEX; rerun with -h for copyright info
# ==15683== Command: ./madd_nano 16384 0
# ==15683==
# --15683-- Warning: Cannot auto-detect cache config, using defaults.
# --15683--          Run with -v to see.
# 2260175,2567551,1.135997,0.253938,0.000652,0.014784,23733,1605341
# ==15683==
# ==15683== I   refs:      6,874,876
# ==15683== I1  misses:        1,483
# ==15683== LLi misses:        1,274
# ==15683== I1  miss rate:      0.02%
# ==15683== LLi miss rate:      0.02%
# ==15683==
# ==15683== D   refs:      3,009,915  (1,847,749 rd   + 1,162,166 wr)
# ==15683== D1  misses:       13,789  (    2,862 rd   +    10,927 wr)
# ==15683== LLd misses:       13,035  (    2,178 rd   +    10,857 wr)
# ==15683== D1  miss rate:       0.5% (      0.2%     +       0.9%  )
# ==15683== LLd miss rate:       0.4% (      0.1%     +       0.9%  )
# ==15683==
# ==15683== LL refs:          15,272  (    4,345 rd   +    10,927 wr)
# ==15683== LL misses:        14,309  (    3,452 rd   +    10,857 wr)
# ==15683== LL miss rate:        0.1% (      0.0%     +       0.9%  )

# %% [markdown]
# Too much detail! Let's use grep to narrow down the outputs.

# %%
# Run it "without" the above code.
! ssh htseng@nano-2 "cd courses/CSE142/demo/memory/4way_madd/; valgrind --tool=cachegrind ./madd_nano 8192 0 >& nano_without_loop.perf; grep 'D   refs\|D1' nano_without_loop.perf"
# Out:
# ==15722== D   refs:      1,535,330  (946,607 rd   + 588,723 wr)
# ==15722== D1  misses:        8,672  (  2,865 rd   +   5,807 wr)
# ==15722== D1  miss rate:       0.6% (    0.3%     +     1.0%  )

# %% [markdown]
# Let's run it with the above loop code again and observe the changes in L1 cache misses/accesses
#
# #### Run with the 4-way matrix add loop code.

# %%
! ssh htseng@nano-2 "cd courses/CSE142/demo/memory/4way_madd/;valgrind --tool=cachegrind ./madd_nano 8192 8192 >& nano_with_loop.perf; grep 'D   refs\|D1' nano_with_loop.perf"
# Out:
# ==15762== D   refs:      1,576,375  (979,438 rd   + 596,937 wr)
# ==15762== D1  misses:       49,650  ( 35,649 rd   +  14,001 wr)
# ==15762== D1  miss rate:       3.1% (    3.6%     +     2.3%  )

# %%
# Let's do some math here
total_number_of_accesses_before_the_loop =    1527773
total_number_of_accesses_after_the_loop =  1548265
total_number_of_accesses_in_the_loop = total_number_of_accesses_after_the_loop-total_number_of_accesses_before_the_loop
total_number_of_misses_before_the_loop =  8538
total_number_of_misses_after_the_loop = 29031
total_number_of_misses_in_the_loop = total_number_of_misses_after_the_loop-total_number_of_misses_before_the_loop
miss_rate_of_the_loop = total_number_of_misses_in_the_loop/total_number_of_accesses_in_the_loop

print(f"access in the loop: %d misses in the loop %d miss_rate %lf" % (total_number_of_accesses_in_the_loop, total_number_of_misses_in_the_loop, miss_rate_of_the_loop))
# Out:
# access in the loop: 20492 misses in the loop 20493 miss_rate 1.000049

# %%
! echo "CPU, IC, Cycles, CPI, CT, ET, miss_rate, misses, accesses" >& ./4way_madd/4way_add.csv
! echo -n "Jetson Nano," >> ./4way_madd/4way_add.csv
! ssh htseng@nano-2 "cd courses/CSE142/demo/memory/4way_madd/; ./madd_nano 16384 16384 >> 4way_add.csv"

# %%
! cd 4way_madd; make clean madd_dump; cd ..; 
# !echo "element,address"> addresses_madd.csv; 
# !./4way_madd/madd_dump 8192 8192 2>> addresses_madd.csv
! head -n 101 addresses_madd.csv > addresses_digest.csv
df = pd.read_csv("addresses_digest.csv",skipfooter=1,engine='python')
df["address"] = df["address"].str.replace('0x','')
df["address"]=df[["address"]].apply(lambda x: x.astype(str).map(lambda x: int(x, base=16)))
# only show the first N addresses 
#N = 32
#df2 = df2.iloc[:N]
C = 32768
B = 64
A = 4
offset_bits = int(math.log2(B))
S = int(C/(B*A))
index_bits = int(math.log2(S))
df["tag"]=(df["address"].apply(lambda x: x >> (offset_bits+index_bits)))
df["tag"] = df["tag"].apply(lambda x: hex(x))
df["index"] = df["address"].apply(lambda x: hex((x>>offset_bits)%S))
df["address"] = df["address"].apply(lambda x: hex(x))
display_df_mono(df)
# Out:
# rm -f madd_intel madd_nano *_O3 *~ madd_A_fission cachegrind* *.perf madd_dump
# cc -O3 -DHAVE_LINUX_PERF_EVENT_H -g  -DDUMP perfstats.c madd.c -o madd_dump
# 191526710,77226859,0.403217,0.266047,0.020546,0.000138,11331,82080984
# <style type="text/css">
# #T_fa5fb_row0_col0, #T_fa5fb_row0_col1, #T_fa5fb_row0_col2, #T_fa5fb_row0_col3, #T_fa5fb_row1_col0, #T_fa5fb_row1_col1, #T_fa5fb_row1_col2, #T_fa5fb_row1_col3, #T_fa5fb_row2_col0, #T_fa5fb_row2_col1, #T_fa5fb_row2_col2, #T_fa5fb_row2_col3, #T_fa5fb_row3_col0, #T_fa5fb_row3_col1, #T_fa5fb_row3_col2, #T_fa5fb_row3_col3, #T_fa5fb_row4_col0, #T_fa5fb_row4_col1, #T_fa5fb_row4_col2, #T_fa5fb_row4_col3, #T_fa5fb_row5_col0, #T_fa5fb_row5_col1, #T_fa5fb_row5_col2, #T_fa5fb_row5_col3, #T_fa5fb_row6_col0, #T_fa5fb_row6_col1, #T_fa5fb_row6_col2, #T_fa5fb_row6_col3, #T_fa5fb_row7_col0, #T_fa5fb_row7_col1, #T_fa5fb_row7_col2, #T_fa5fb_row7_col3, #T_fa5fb_row8_col0, #T_fa5fb_row8_col1, #T_fa5fb_row8_col2, #T_fa5fb_row8_col3, #T_fa5fb_row9_col0, #T_fa5fb_row9_col1, #T_fa5fb_row9_col2, #T_fa5fb_row9_col3, #T_fa5fb_row10_col0, #T_fa5fb_row10_col1, #T_fa5fb_row10_col2, #T_fa5fb_row10_col3, #T_fa5fb_row11_col0, #T_fa5fb_row11_col1, #T_fa5fb_row11_col2, #T_fa5fb_row11_col3, #T_fa5fb_row12_col0, #T_fa5fb_row12_col1, #T_fa5fb_row12_col2, #T_fa5fb_row12_col3, #T_fa5fb_row13_col0, #T_fa5fb_row13_col1, #T_fa5fb_row13_col2, #T_fa5fb_row13_col3, #T_fa5fb_row14_col0, #T_fa5fb_row14_col1, #T_fa5fb_row14_col2, #T_fa5fb_row14_col3, #T_fa5fb_row15_col0, #T_fa5fb_row15_col1, #T_fa5fb_row15_col2, #T_fa5fb_row15_col3, #T_fa5fb_row16_col0, #T_fa5fb_row16_col1, #T_fa5fb_row16_col2, #T_fa5fb_row16_col3, #T_fa5fb_row17_col0, #T_fa5fb_row17_col1, #T_fa5fb_row17_col2, #T_fa5fb_row17_col3, #T_fa5fb_row18_col0, #T_fa5fb_row18_col1, #T_fa5fb_row18_col2, #T_fa5fb_row18_col3, #T_fa5fb_row19_col0, #T_fa5fb_row19_col1, #T_fa5fb_row19_col2, #T_fa5fb_row19_col3, #T_fa5fb_row20_col0, #T_fa5fb_row20_col1, #T_fa5fb_row20_col2, #T_fa5fb_row20_col3, #T_fa5fb_row21_col0, #T_fa5fb_row21_col1, #T_fa5fb_row21_col2, #T_fa5fb_row21_col3, #T_fa5fb_row22_col0, #T_fa5fb_row22_col1, #T_fa5fb_row22_col2, #T_fa5fb_row22_col3, #T_fa5fb_row23_col0, #T_fa5fb_row23_col1, #T_fa5fb_row23_col2, #T_fa5fb_row23_col3, #T_fa5fb_row24_col0, #T_fa5fb_row24_col1, #T_fa5fb_row24_col2, #T_fa5fb_row24_col3, #T_fa5fb_row25_col0, #T_fa5fb_row25_col1, #T_fa5fb_row25_col2, #T_fa5fb_row25_col3, #T_fa5fb_row26_col0, #T_fa5fb_row26_col1, #T_fa5fb_row26_col2, #T_fa5fb_row26_col3, #T_fa5fb_row27_col0, #T_fa5fb_row27_col1, #T_fa5fb_row27_col2, #T_fa5fb_row27_col3, #T_fa5fb_row28_col0, #T_fa5fb_row28_col1, #T_fa5fb_row28_col2, #T_fa5fb_row28_col3, #T_fa5fb_row29_col0, #T_fa5fb_row29_col1, #T_fa5fb_row29_col2, #T_fa5fb_row29_col3, #T_fa5fb_row30_col0, #T_fa5fb_row30_col1, #T_fa5fb_row30_col2, #T_fa5fb_row30_col3, #T_fa5fb_row31_col0, #T_fa5fb_row31_col1, #T_fa5fb_row31_col2, #T_fa5fb_row31_col3, #T_fa5fb_row32_col0, #T_fa5fb_row32_col1, #T_fa5fb_row32_col2, #T_fa5fb_row32_col3, #T_fa5fb_row33_col0, #T_fa5fb_row33_col1, #T_fa5fb_row33_col2, #T_fa5fb_row33_col3, #T_fa5fb_row34_col0, #T_fa5fb_row34_col1, #T_fa5fb_row34_col2, #T_fa5fb_row34_col3, #T_fa5fb_row35_col0, #T_fa5fb_row35_col1, #T_fa5fb_row35_col2, #T_fa5fb_row35_col3, #T_fa5fb_row36_col0, #T_fa5fb_row36_col1, #T_fa5fb_row36_col2, #T_fa5fb_row36_col3, #T_fa5fb_row37_col0, #T_fa5fb_row37_col1, #T_fa5fb_row37_col2, #T_fa5fb_row37_col3, #T_fa5fb_row38_col0, #T_fa5fb_row38_col1, #T_fa5fb_row38_col2, #T_fa5fb_row38_col3, #T_fa5fb_row39_col0, #T_fa5fb_row39_col1, #T_fa5fb_row39_col2, #T_fa5fb_row39_col3, #T_fa5fb_row40_col0, #T_fa5fb_row40_col1, #T_fa5fb_row40_col2, #T_fa5fb_row40_col3, #T_fa5fb_row41_col0, #T_fa5fb_row41_col1, #T_fa5fb_row41_col2, #T_fa5fb_row41_col3, #T_fa5fb_row42_col0, #T_fa5fb_row42_col1, #T_fa5fb_row42_col2, #T_fa5fb_row42_col3, #T_fa5fb_row43_col0, #T_fa5fb_row43_col1, #T_fa5fb_row43_col2, #T_fa5fb_row43_col3, #T_fa5fb_row44_col0, #T_fa5fb_row44_col1, #T_fa5fb_row44_col2, #T_fa5fb_row44_col3, #T_fa5fb_row45_col0, #T_fa5fb_row45_col1, #T_fa5fb_row45_col2, #T_fa5fb_row45_col3, #T_fa5fb_row46_col0, #T_fa5fb_row46_col1, #T_fa5fb_row46_col2, #T_fa5fb_row46_col3, #T_fa5fb_row47_col0, #T_fa5fb_row47_col1, #T_fa5fb_row47_col2, #T_fa5fb_row47_col3, #T_fa5fb ...

# %% [markdown]
# ### Intel Core i7 13700 -- 12-way L1, 64B-blocked, 48KB cache
#
# Let's run it without the above loop code to figure the baseline memory accesses without running the loop on a Jetson nano.
#
# Let's again dump, parse and simulation the address sequence.

# %%
! cd 4way_madd; make madd_dump; cd ..; 
# !echo "element,address"> addresses_madd.csv; 
# !./4way_madd/madd_dump 8192 8192 2>> addresses_madd.csv
! head -n 101 addresses_madd.csv > addresses_digest.csv
df = pd.read_csv("addresses_digest.csv",skipfooter=1,engine='python')
df["address"] = df["address"].str.replace('0x','')
df["address"]=df[["address"]].apply(lambda x: x.astype(str).map(lambda x: int(x, base=16)))
# only show the first N addresses 
#N = 32
#df2 = df2.iloc[:N]
C = 49152
B = 64
A = 12
offset_bits = int(math.log2(B))
S = int(C/(B*A))
index_bits = int(math.log2(S))
df["tag"]=(df["address"].apply(lambda x: x >> (offset_bits+index_bits)))
df["tag"] = df["tag"].apply(lambda x: hex(x))
df["index"] = df["address"].apply(lambda x: hex((x>>offset_bits) % S))
df["address"] = df["address"].apply(lambda x: hex(x))
display_df_mono(df)
# Out:
# make: 'madd_dump' is up to date.
# 191512690,77884910,0.406683,0.263684,0.020537,0.000133,10891,82076806
# <style type="text/css">
# #T_8ac69_row0_col0, #T_8ac69_row0_col1, #T_8ac69_row0_col2, #T_8ac69_row0_col3, #T_8ac69_row1_col0, #T_8ac69_row1_col1, #T_8ac69_row1_col2, #T_8ac69_row1_col3, #T_8ac69_row2_col0, #T_8ac69_row2_col1, #T_8ac69_row2_col2, #T_8ac69_row2_col3, #T_8ac69_row3_col0, #T_8ac69_row3_col1, #T_8ac69_row3_col2, #T_8ac69_row3_col3, #T_8ac69_row4_col0, #T_8ac69_row4_col1, #T_8ac69_row4_col2, #T_8ac69_row4_col3, #T_8ac69_row5_col0, #T_8ac69_row5_col1, #T_8ac69_row5_col2, #T_8ac69_row5_col3, #T_8ac69_row6_col0, #T_8ac69_row6_col1, #T_8ac69_row6_col2, #T_8ac69_row6_col3, #T_8ac69_row7_col0, #T_8ac69_row7_col1, #T_8ac69_row7_col2, #T_8ac69_row7_col3, #T_8ac69_row8_col0, #T_8ac69_row8_col1, #T_8ac69_row8_col2, #T_8ac69_row8_col3, #T_8ac69_row9_col0, #T_8ac69_row9_col1, #T_8ac69_row9_col2, #T_8ac69_row9_col3, #T_8ac69_row10_col0, #T_8ac69_row10_col1, #T_8ac69_row10_col2, #T_8ac69_row10_col3, #T_8ac69_row11_col0, #T_8ac69_row11_col1, #T_8ac69_row11_col2, #T_8ac69_row11_col3, #T_8ac69_row12_col0, #T_8ac69_row12_col1, #T_8ac69_row12_col2, #T_8ac69_row12_col3, #T_8ac69_row13_col0, #T_8ac69_row13_col1, #T_8ac69_row13_col2, #T_8ac69_row13_col3, #T_8ac69_row14_col0, #T_8ac69_row14_col1, #T_8ac69_row14_col2, #T_8ac69_row14_col3, #T_8ac69_row15_col0, #T_8ac69_row15_col1, #T_8ac69_row15_col2, #T_8ac69_row15_col3, #T_8ac69_row16_col0, #T_8ac69_row16_col1, #T_8ac69_row16_col2, #T_8ac69_row16_col3, #T_8ac69_row17_col0, #T_8ac69_row17_col1, #T_8ac69_row17_col2, #T_8ac69_row17_col3, #T_8ac69_row18_col0, #T_8ac69_row18_col1, #T_8ac69_row18_col2, #T_8ac69_row18_col3, #T_8ac69_row19_col0, #T_8ac69_row19_col1, #T_8ac69_row19_col2, #T_8ac69_row19_col3, #T_8ac69_row20_col0, #T_8ac69_row20_col1, #T_8ac69_row20_col2, #T_8ac69_row20_col3, #T_8ac69_row21_col0, #T_8ac69_row21_col1, #T_8ac69_row21_col2, #T_8ac69_row21_col3, #T_8ac69_row22_col0, #T_8ac69_row22_col1, #T_8ac69_row22_col2, #T_8ac69_row22_col3, #T_8ac69_row23_col0, #T_8ac69_row23_col1, #T_8ac69_row23_col2, #T_8ac69_row23_col3, #T_8ac69_row24_col0, #T_8ac69_row24_col1, #T_8ac69_row24_col2, #T_8ac69_row24_col3, #T_8ac69_row25_col0, #T_8ac69_row25_col1, #T_8ac69_row25_col2, #T_8ac69_row25_col3, #T_8ac69_row26_col0, #T_8ac69_row26_col1, #T_8ac69_row26_col2, #T_8ac69_row26_col3, #T_8ac69_row27_col0, #T_8ac69_row27_col1, #T_8ac69_row27_col2, #T_8ac69_row27_col3, #T_8ac69_row28_col0, #T_8ac69_row28_col1, #T_8ac69_row28_col2, #T_8ac69_row28_col3, #T_8ac69_row29_col0, #T_8ac69_row29_col1, #T_8ac69_row29_col2, #T_8ac69_row29_col3, #T_8ac69_row30_col0, #T_8ac69_row30_col1, #T_8ac69_row30_col2, #T_8ac69_row30_col3, #T_8ac69_row31_col0, #T_8ac69_row31_col1, #T_8ac69_row31_col2, #T_8ac69_row31_col3, #T_8ac69_row32_col0, #T_8ac69_row32_col1, #T_8ac69_row32_col2, #T_8ac69_row32_col3, #T_8ac69_row33_col0, #T_8ac69_row33_col1, #T_8ac69_row33_col2, #T_8ac69_row33_col3, #T_8ac69_row34_col0, #T_8ac69_row34_col1, #T_8ac69_row34_col2, #T_8ac69_row34_col3, #T_8ac69_row35_col0, #T_8ac69_row35_col1, #T_8ac69_row35_col2, #T_8ac69_row35_col3, #T_8ac69_row36_col0, #T_8ac69_row36_col1, #T_8ac69_row36_col2, #T_8ac69_row36_col3, #T_8ac69_row37_col0, #T_8ac69_row37_col1, #T_8ac69_row37_col2, #T_8ac69_row37_col3, #T_8ac69_row38_col0, #T_8ac69_row38_col1, #T_8ac69_row38_col2, #T_8ac69_row38_col3, #T_8ac69_row39_col0, #T_8ac69_row39_col1, #T_8ac69_row39_col2, #T_8ac69_row39_col3, #T_8ac69_row40_col0, #T_8ac69_row40_col1, #T_8ac69_row40_col2, #T_8ac69_row40_col3, #T_8ac69_row41_col0, #T_8ac69_row41_col1, #T_8ac69_row41_col2, #T_8ac69_row41_col3, #T_8ac69_row42_col0, #T_8ac69_row42_col1, #T_8ac69_row42_col2, #T_8ac69_row42_col3, #T_8ac69_row43_col0, #T_8ac69_row43_col1, #T_8ac69_row43_col2, #T_8ac69_row43_col3, #T_8ac69_row44_col0, #T_8ac69_row44_col1, #T_8ac69_row44_col2, #T_8ac69_row44_col3, #T_8ac69_row45_col0, #T_8ac69_row45_col1, #T_8ac69_row45_col2, #T_8ac69_row45_col3, #T_8ac69_row46_col0, #T_8ac69_row46_col1, #T_8ac69_row46_col2, #T_8ac69_row46_col3, #T_8ac69_row47_col0, #T_8ac69_row47_col1, #T_8ac69_row47_col2, #T_8ac69_row47_col3, #T_8ac69 ...

# %% [markdown]
# #### Run with performance counters

# %%
# Run it "without" the above code.
! make -C ./4way_madd/ madd_intel 
! echo -n "Intel Core i7 13700," >> ./4way_madd/4way_add.csv
! lscpu; cd ~/courses/CSE142/demo/memory/4way_madd/; ./madd_intel 16384 16384 >> 4way_add.csv
# Out:
# make: Entering directory '/nfshome/htseng/courses/CSE142/demo/memory/4way_madd'
# make: 'madd_intel' is up to date.
# make: Leaving directory '/nfshome/htseng/courses/CSE142/demo/memory/4way_madd'
# Architecture:             x86_64
#   CPU op-mode(s):         32-bit, 64-bit
#   Address sizes:          46 bits physical, 48 bits virtual
#   Byte Order:             Little Endian
# CPU(s):                   24
#   On-line CPU(s) list:    0-23
# Vendor ID:                GenuineIntel
#   Model name:             13th Gen Intel(R) Core(TM) i7-13700
#     CPU family:           6
#     Model:                183
#     Thread(s) per core:   2
#     Core(s) per socket:   16
#     Socket(s):            1
#     Stepping:             1
#     CPU(s) scaling MHz:   18%
#     CPU max MHz:          5200.0000
#     CPU min MHz:          800.0000
#     BogoMIPS:             4224.00
#     Flags:                fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge m
#                           ca cmov pat pse36 clflush dts acpi mmx fxsr sse sse2 s
#                           s ht tm pbe syscall nx pdpe1gb rdtscp lm constant_tsc
#                           art arch_perfmon pebs bts rep_good nopl xtopology nons
#                           top_tsc cpuid aperfmperf tsc_known_freq pni pclmulqdq
#                           dtes64 monitor ds_cpl vmx smx est tm2 ssse3 sdbg fma c
#                           x16 xtpr pdcm pcid sse4_1 sse4_2 x2apic movbe popcnt t
#                           sc_deadline_timer aes xsave avx f16c rdrand lahf_lm ab
#                           m 3dnowprefetch cpuid_fault ssbd ibrs ibpb stibp ibrs_
#                           enhanced tpr_shadow flexpriority ept vpid ept_ad fsgsb
#                           ase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid rdseed
#                            adx smap clflushopt clwb intel_pt sha_ni xsaveopt xsa
#                           vec xgetbv1 xsaves split_lock_detect user_shstk avx_vn
#                           ni dtherm ida arat pln pts hwp hwp_notify hwp_act_wind
#                           ow hwp_epp hwp_pkg_req hfi vnmi umip pku ospke waitpkg
#                            gfni vaes vpclmulqdq tme rdpid movdiri movdir64b fsrm
#                            md_clear serialize pconfig arch_lbr ibt flush_l1d arc
#                           h_capabilities
# Virtualization features:
#   Virtualization:         VT-x
# Caches (sum of all):
#   L1d:                    640 KiB (16 instances)
#   L1i:                    768 KiB (16 instances)
#   L2:                     24 MiB (10 instances)
#   L3:                     30 MiB (1 instance)
# NUMA:
#   NUMA node(s):           1
#   NUMA node0 CPU(s):      0-23
# Vulnerabilities:
#   Gather data sampling:   Not affected
#   Itlb multihit:          Not affected
#   L1tf:                   Not affected
#   Mds:                    Not affected
#   Meltdown:               Not affected
#   Mmio stale data:        Not affected
#   Reg file data sampling: Mitigation; Clear Register File
#   Retbleed:               Not affected
#   Spec rstack overflow:   Not affected
#   Spec store bypass:      Mitigation; Speculative Store Bypass disabled via prct
#                           l
#   Spectre v1:             Mitigation; usercopy/swapgs barriers and __user pointe
#                           r sanitization
#   Spectre v2:             Mitigation; Enhanced / Automatic IBRS; IBPB conditiona
#                           l; RSB filling; PBRSB-eIBRS SW sequence; BHI BHI_DIS_S
#   Srbds:                  Not affected
#   Tsx async abort:        Not affected

# %% [markdown]
# Let's run it with the above loop code again and observe the changes in L1 cache misses/accesses
#
# #### Run with the 4-way matrix add loop code.

# %%
# Run it "with" the above code.
! cd ~/courses/CSE142/demo/memory/4way_madd/; valgrind --tool=cachegrind ./madd_intel 16384 16384  >& intel_with_loop.perf; grep 'D   refs\|D1' intel_with_loop.perf

# %%
# Let's do some math here
total_number_of_accesses_before_the_loop =2285911
total_number_of_accesses_after_the_loop = 2326877
total_number_of_accesses_in_the_loop = total_number_of_accesses_after_the_loop-total_number_of_accesses_before_the_loop
total_number_of_misses_before_the_loop = 13447
total_number_of_misses_after_the_loop = 23694
total_number_of_misses_in_the_loop = total_number_of_misses_after_the_loop-total_number_of_misses_before_the_loop
miss_rate_of_the_loop = total_number_of_misses_in_the_loop/total_number_of_accesses_in_the_loop

print(f"access in the loop: %d misses in the loop %d miss_rate %lf" % (total_number_of_accesses_in_the_loop, total_number_of_misses_in_the_loop, miss_rate_of_the_loop))
# Out:
# access in the loop: 40966 misses in the loop 10247 miss_rate 0.250134

# %%
display_df_mono(render_csv("./4way_madd/4way_add.csv"))
# Out:
# <style type="text/css">
# #T_f1153_row0_col0, #T_f1153_row0_col1, #T_f1153_row0_col2, #T_f1153_row0_col3, #T_f1153_row0_col4, #T_f1153_row0_col5, #T_f1153_row0_col6, #T_f1153_row0_col7, #T_f1153_row0_col8, #T_f1153_row0_col9, #T_f1153_row1_col0, #T_f1153_row1_col1, #T_f1153_row1_col2, #T_f1153_row1_col3, #T_f1153_row1_col4, #T_f1153_row1_col5, #T_f1153_row1_col6, #T_f1153_row1_col7, #T_f1153_row1_col8, #T_f1153_row1_col9, #T_f1153_row2_col0, #T_f1153_row2_col1, #T_f1153_row2_col2, #T_f1153_row2_col3, #T_f1153_row2_col4, #T_f1153_row2_col5, #T_f1153_row2_col6, #T_f1153_row2_col7, #T_f1153_row2_col8, #T_f1153_row2_col9 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_f1153">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1153_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_f1153_level0_col1" class="col_heading level0 col1" >CPU</th>
#       <th id="T_f1153_level0_col2" class="col_heading level0 col2" > IC</th>
#       <th id="T_f1153_level0_col3" class="col_heading level0 col3" > Cycles</th>
#       <th id="T_f1153_level0_col4" class="col_heading level0 col4" > CPI</th>
#       <th id="T_f1153_level0_col5" class="col_heading level0 col5" > CT</th>
#       <th id="T_f1153_level0_col6" class="col_heading level0 col6" > ET</th>
#       <th id="T_f1153_level0_col7" class="col_heading level0 col7" > miss_rate</th>
#       <th id="T_f1153_level0_col8" class="col_heading level0 col8" > misses</th>
#       <th id="T_f1153_level0_col9" class="col_heading level0 col9" > accesses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1153_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f1153_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_f1153_row0_col1" class="data row0 col1" >Jetson Nano</td>
#       <td id="T_f1153_row0_col2" class="data row0 col2" >198632</td>
#       <td id="T_f1153_row0_col3" class="data row0 col3" >487539</td>
#       <td id="T_f1153_row0_col4" class="data row0 col4" >2.454484</td>
#       <td id="T_f1153_row0_col5" class="data row0 col5" >0.758914</td>
#       <td id="T_f1153_row0_col6" class="data row0 col6" >0.000370</td>
#       <td id="T_f1153_row0_col7" class="data row0 col7" >0.117226</td>
#       <td id="T_f1153_row0_col8" class="data row0 col8" >21095</td>
#       <td id="T_f1153_row0_col9" class="data row0 col9" >179951</td>
#     </tr>
#     <tr>
#       <th id="T_f1153_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f1153_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_f1153_row1_col1" class="data row1 col1" >Intel Core i7 13700</td>
#       <td id="T_f1153_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_f1153_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_f1153_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_f1153_row1_col5" class="data row1 col5" >inf</td>
#       <td id="T_f1153_row1_col6" class="data row1 col6" >0.000165</td>
#       <td id="T_f1153_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_f1153_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_f1153_row1_col9" class="data row1 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f1153_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f1153_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_f1153_row2_col1" class="data row2 col1" >Intel Core i7 13700</td>
#       <td id="T_f1153_row2_col2" class="data row2 col2" >102678</td>
#       <td id="T_f1153_row2_col3" class="data row2 col3" >94163</td>
#       <td id="T_f1153_row2_col4" class="data row2 col4" >0.917071</td>
#       <td id="T_f1153_row2_col5" class="data row2 col5" >0.477895</td>
#       <td id="T_f1153_row2_col6" class="data row2 col6" >0.000045</td>
#       <td id="T_f1153_row2_col7" class="data row2 col7" >0.134357</td>
#       <td id="T_f1153_row2_col8" class="data row2 col8" >6162</td>
#       <td id="T_f1153_row2_col9" class="data row2 col9" >45863</td>
#     </tr>
#   </tbody>
# </table>

# %%
! cat ./4way_madd/4way_add.csv
# Out:
# CPU, IC, Cycles, CPI, CT, ET, miss_rate, misses, accesses
# Jetson Nano,198632,487539,2.454484,0.758914,0.000370,0.117226,21095,179951
# Intel Core i7 13700,0,0,-nan,inf,0.000165,-nan,0,0
