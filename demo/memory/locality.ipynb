# %%
# Please execute/shift-return this cell everytime you run the notebook.  Don't edit it. 
# %load_ext autoreload
# %autoreload 2
from notebook import *
# Out:
# /nfshome/htseng/courses/CS203/demo/memory/notebook.py:229: SyntaxWarning: invalid escape sequence '\s'
#   show = (f"[\s\*]{show}\s*\(", "^\}")
# /nfshome/htseng/courses/CS203/demo/memory/notebook.py:229: SyntaxWarning: invalid escape sequence '\s'
#   show = (f"[\s\*]{show}\s*\(", "^\}")
# /nfshome/htseng/courses/CS203/demo/memory/notebook.py:229: SyntaxWarning: invalid escape sequence '\}'
#   show = (f"[\s\*]{show}\s*\(", "^\}")
# <style>h1 {font-size: 2vw;} h2 {font-size: 1.5vw;} p {font-size: 1.4vw;} div.prompt, code, output, prompt, kbd, pre, samp {font-family: 'SF Mono', 'Courier New', Courier, monospace, sans-serif !important;font-size: 1.4vw !important;}</style>

# %% [markdown]
# # The "Locality" of my code
#
# Take a look of matrix vector:

# %%
render_code("./mv/matvec.c", lang="c++", show=["//I_FIRST_START", "//I_FIRST_END"])
# Out:
# // ./mv/matvec.c:35-49 (15 lines)
#   //I_FIRST_START
#     for(i = 0; i < ARRAY_SIZE; i++)
#     {
#       result = 0.0;
#       for(j = 0; j < ARRAY_SIZE; j++)
#       {
#         result += a[i][j]*b[j];
#         if(dump)
#             printf("&a[%d][%d], %p\n&b[%d], %p\n", i, j, &a[i][j], j, &b[j]);
#       }
#       c[i] = result;
#       if(dump)
#           printf("&c[%d], %p\n", i, &c[i]);
#     }
#   //I_FIRST_END

# %%
! cd mv; make clean; make; ./matvec 16 1 1 >> mv_addresses.csv ; head -n 100 mv_addresses.csv
# Out:
# rm -f matvec
# cc -DHAVE_LINUX_PERF_EVENT_H -g -O3  matvec.c -o matvec
# &a[0][0], 0x55ac54a78330
# &b[0], 0x55ac54a78c30
# &a[0][1], 0x55ac54a78338
# &b[1], 0x55ac54a78c38
# &a[0][2], 0x55ac54a78340
# &b[2], 0x55ac54a78c40
# &a[0][3], 0x55ac54a78348
# &b[3], 0x55ac54a78c48
# &a[0][4], 0x55ac54a78350
# &b[4], 0x55ac54a78c50
# &a[0][5], 0x55ac54a78358
# &b[5], 0x55ac54a78c58
# &a[0][6], 0x55ac54a78360
# &b[6], 0x55ac54a78c60
# &a[0][7], 0x55ac54a78368
# &b[7], 0x55ac54a78c68
# &a[0][8], 0x55ac54a78370
# &b[8], 0x55ac54a78c70
# &a[0][9], 0x55ac54a78378
# &b[9], 0x55ac54a78c78
# &a[0][10], 0x55ac54a78380
# &b[10], 0x55ac54a78c80
# &a[0][11], 0x55ac54a78388
# &b[11], 0x55ac54a78c88
# &a[0][12], 0x55ac54a78390
# &b[12], 0x55ac54a78c90
# &a[0][13], 0x55ac54a78398
# &b[13], 0x55ac54a78c98
# &a[0][14], 0x55ac54a783a0
# &b[14], 0x55ac54a78ca0
# &a[0][15], 0x55ac54a783a8
# &b[15], 0x55ac54a78ca8
# &c[0], 0x55ac54a78cc0
# &a[1][0], 0x55ac54a783c0
# &b[0], 0x55ac54a78c30
# &a[1][1], 0x55ac54a783c8
# &b[1], 0x55ac54a78c38
# &a[1][2], 0x55ac54a783d0
# &b[2], 0x55ac54a78c40
# &a[1][3], 0x55ac54a783d8
# &b[3], 0x55ac54a78c48
# &a[1][4], 0x55ac54a783e0
# &b[4], 0x55ac54a78c50
# &a[1][5], 0x55ac54a783e8
# &b[5], 0x55ac54a78c58
# &a[1][6], 0x55ac54a783f0
# &b[6], 0x55ac54a78c60
# &a[1][7], 0x55ac54a783f8
# &b[7], 0x55ac54a78c68
# &a[1][8], 0x55ac54a78400
# &b[8], 0x55ac54a78c70
# &a[1][9], 0x55ac54a78408
# &b[9], 0x55ac54a78c78
# &a[1][10], 0x55ac54a78410
# &b[10], 0x55ac54a78c80
# &a[1][11], 0x55ac54a78418
# &b[11], 0x55ac54a78c88
# &a[1][12], 0x55ac54a78420
# &b[12], 0x55ac54a78c90
# &a[1][13], 0x55ac54a78428
# &b[13], 0x55ac54a78c98
# &a[1][14], 0x55ac54a78430
# &b[14], 0x55ac54a78ca0
# &a[1][15], 0x55ac54a78438
# &b[15], 0x55ac54a78ca8
# &c[1], 0x55ac54a78cc8
# &a[2][0], 0x55ac54a78450
# &b[0], 0x55ac54a78c30
# &a[2][1], 0x55ac54a78458
# &b[1], 0x55ac54a78c38
# &a[2][2], 0x55ac54a78460
# &b[2], 0x55ac54a78c40
# &a[2][3], 0x55ac54a78468
# &b[3], 0x55ac54a78c48
# &a[2][4], 0x55ac54a78470
# &b[4], 0x55ac54a78c50
# &a[2][5], 0x55ac54a78478
# &b[5], 0x55ac54a78c58
# &a[2][6], 0x55ac54a78480
# &b[6], 0x55ac54a78c60
# &a[2][7], 0x55ac54a78488
# &b[7], 0x55ac54a78c68
# &a[2][8], 0x55ac54a78490
# &b[8], 0x55ac54a78c70
# &a[2][9], 0x55ac54a78498
# &b[9], 0x55ac54a78c78
# &a[2][10], 0x55ac54a784a0
# &b[10], 0x55ac54a78c80
# &a[2][11], 0x55ac54a784a8
# &b[11], 0x55ac54a78c88
# &a[2][12], 0x55ac54a784b0
# &b[12], 0x55ac54a78c90
# &a[2][13], 0x55ac54a784b8
# &b[13], 0x55ac54a78c98
# &a[2][14], 0x55ac54a784c0
# &b[14], 0x55ac54a78ca0
# &a[2][15], 0x55ac54a784c8
# &b[15], 0x55ac54a78ca8
# &c[2], 0x55ac54a78cd0
# &a[3][0], 0x55ac54a784e0

# %%
! cd mv; ./matvec 16 1 0 >> mv_addresses_j_first.csv ; head -n 100 mv_addresses_j_first.csv
# Out:
# &a[0][0], 0x55e60cd61330
# &b[0], 0x55e60cd61c30
# &a[1][0], 0x55e60cd613c0
# &b[0], 0x55e60cd61c30
# &a[2][0], 0x55e60cd61450
# &b[0], 0x55e60cd61c30
# &a[3][0], 0x55e60cd614e0
# &b[0], 0x55e60cd61c30
# &a[4][0], 0x55e60cd61570
# &b[0], 0x55e60cd61c30
# &a[5][0], 0x55e60cd61600
# &b[0], 0x55e60cd61c30
# &a[6][0], 0x55e60cd61690
# &b[0], 0x55e60cd61c30
# &a[7][0], 0x55e60cd61720
# &b[0], 0x55e60cd61c30
# &a[8][0], 0x55e60cd617b0
# &b[0], 0x55e60cd61c30
# &a[9][0], 0x55e60cd61840
# &b[0], 0x55e60cd61c30
# &a[10][0], 0x55e60cd618d0
# &b[0], 0x55e60cd61c30
# &a[11][0], 0x55e60cd61960
# &b[0], 0x55e60cd61c30
# &a[12][0], 0x55e60cd619f0
# &b[0], 0x55e60cd61c30
# &a[13][0], 0x55e60cd61a80
# &b[0], 0x55e60cd61c30
# &a[14][0], 0x55e60cd61b10
# &b[0], 0x55e60cd61c30
# &a[15][0], 0x55e60cd61ba0
# &b[0], 0x55e60cd61c30
# &c[16], 0x55e60cd61d40
# &a[0][1], 0x55e60cd61338
# &b[1], 0x55e60cd61c38
# &a[1][1], 0x55e60cd613c8
# &b[1], 0x55e60cd61c38
# &a[2][1], 0x55e60cd61458
# &b[1], 0x55e60cd61c38
# &a[3][1], 0x55e60cd614e8
# &b[1], 0x55e60cd61c38
# &a[4][1], 0x55e60cd61578
# &b[1], 0x55e60cd61c38
# &a[5][1], 0x55e60cd61608
# &b[1], 0x55e60cd61c38
# &a[6][1], 0x55e60cd61698
# &b[1], 0x55e60cd61c38
# &a[7][1], 0x55e60cd61728
# &b[1], 0x55e60cd61c38
# &a[8][1], 0x55e60cd617b8
# &b[1], 0x55e60cd61c38
# &a[9][1], 0x55e60cd61848
# &b[1], 0x55e60cd61c38
# &a[10][1], 0x55e60cd618d8
# &b[1], 0x55e60cd61c38
# &a[11][1], 0x55e60cd61968
# &b[1], 0x55e60cd61c38
# &a[12][1], 0x55e60cd619f8
# &b[1], 0x55e60cd61c38
# &a[13][1], 0x55e60cd61a88
# &b[1], 0x55e60cd61c38
# &a[14][1], 0x55e60cd61b18
# &b[1], 0x55e60cd61c38
# &a[15][1], 0x55e60cd61ba8
# &b[1], 0x55e60cd61c38
# &c[16], 0x55e60cd61d40
# &a[0][2], 0x55e60cd61340
# &b[2], 0x55e60cd61c40
# &a[1][2], 0x55e60cd613d0
# &b[2], 0x55e60cd61c40
# &a[2][2], 0x55e60cd61460
# &b[2], 0x55e60cd61c40
# &a[3][2], 0x55e60cd614f0
# &b[2], 0x55e60cd61c40
# &a[4][2], 0x55e60cd61580
# &b[2], 0x55e60cd61c40
# &a[5][2], 0x55e60cd61610
# &b[2], 0x55e60cd61c40
# &a[6][2], 0x55e60cd616a0
# &b[2], 0x55e60cd61c40
# &a[7][2], 0x55e60cd61730
# &b[2], 0x55e60cd61c40
# &a[8][2], 0x55e60cd617c0
# &b[2], 0x55e60cd61c40
# &a[9][2], 0x55e60cd61850
# &b[2], 0x55e60cd61c40
# &a[10][2], 0x55e60cd618e0
# &b[2], 0x55e60cd61c40
# &a[11][2], 0x55e60cd61970
# &b[2], 0x55e60cd61c40
# &a[12][2], 0x55e60cd61a00
# &b[2], 0x55e60cd61c40
# &a[13][2], 0x55e60cd61a90
# &b[2], 0x55e60cd61c40
# &a[14][2], 0x55e60cd61b20
# &b[2], 0x55e60cd61c40
# &a[15][2], 0x55e60cd61bb0
# &b[2], 0x55e60cd61c40
# &c[16], 0x55e60cd61d40
# &a[0][3], 0x55e60cd61348
