# %%
# %load_ext autoreload
# %autoreload 2
from notebook import *
# if get something about NUMEXPR_MAX_THREADS being set incorrectly, don't worry.  It's not a problem.
# Out:
# <style>h1 {font-size: 2vw;} h2 {font-size: 1.5vw;} p {font-size: 1.4vw;} div.prompt, code, output, prompt, kbd, pre, samp {font-family: 'SF Mono', 'Courier New', Courier, monospace, sans-serif !important;font-size: 1.4vw !important;}</style>

# %% [markdown]
# ## Chip Multiprocessors (CMP)
#
# Let's try run them on separate cores.

# %%
! echo "IC,Cycles,CPI,CT,ET,L1_dcache_miss_rate,L1_dcache_misses,L1_dcache_accesses,branches,branch_misses" > stats.csv
! taskset -c 10 ./mv/matvec 16384 & taskset -c 8 ./mv/matvec 16384
# Out:
# 41845914.000000,41745652
# 41845914.000000,41745652

# %%
display_df_mono(render_csv("stats.csv"))
# !cp stats.csv two_identical_cmp.csv
# Out:
# <style type="text/css">
# #T_10760_row0_col0, #T_10760_row0_col1, #T_10760_row0_col2, #T_10760_row0_col3, #T_10760_row0_col4, #T_10760_row0_col5, #T_10760_row0_col6, #T_10760_row0_col7, #T_10760_row0_col8, #T_10760_row0_col9, #T_10760_row0_col10, #T_10760_row1_col0, #T_10760_row1_col1, #T_10760_row1_col2, #T_10760_row1_col3, #T_10760_row1_col4, #T_10760_row1_col5, #T_10760_row1_col6, #T_10760_row1_col7, #T_10760_row1_col8, #T_10760_row1_col9, #T_10760_row1_col10 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_10760">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10760_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_10760_level0_col1" class="col_heading level0 col1" >IC</th>
#       <th id="T_10760_level0_col2" class="col_heading level0 col2" >Cycles</th>
#       <th id="T_10760_level0_col3" class="col_heading level0 col3" >CPI</th>
#       <th id="T_10760_level0_col4" class="col_heading level0 col4" >CT</th>
#       <th id="T_10760_level0_col5" class="col_heading level0 col5" >ET</th>
#       <th id="T_10760_level0_col6" class="col_heading level0 col6" >L1_dcache_miss_rate</th>
#       <th id="T_10760_level0_col7" class="col_heading level0 col7" >L1_dcache_misses</th>
#       <th id="T_10760_level0_col8" class="col_heading level0 col8" >L1_dcache_accesses</th>
#       <th id="T_10760_level0_col9" class="col_heading level0 col9" >branches</th>
#       <th id="T_10760_level0_col10" class="col_heading level0 col10" >branch_misses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10760_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_10760_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_10760_row0_col1" class="data row0 col1" >1209865948</td>
#       <td id="T_10760_row0_col2" class="data row0 col2" >856651493</td>
#       <td id="T_10760_row0_col3" class="data row0 col3" >0.708055</td>
#       <td id="T_10760_row0_col4" class="data row0 col4" >0.179735</td>
#       <td id="T_10760_row0_col5" class="data row0 col5" >0.153970</td>
#       <td id="T_10760_row0_col6" class="data row0 col6" >0.029107</td>
#       <td id="T_10760_row0_col7" class="data row0 col7" >7832249</td>
#       <td id="T_10760_row0_col8" class="data row0 col8" >269086339</td>
#       <td id="T_10760_row0_col9" class="data row0 col9" >134572897</td>
#       <td id="T_10760_row0_col10" class="data row0 col10" >29361</td>
#     </tr>
#     <tr>
#       <th id="T_10760_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_10760_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_10760_row1_col1" class="data row1 col1" >1209670383</td>
#       <td id="T_10760_row1_col2" class="data row1 col2" >933445193</td>
#       <td id="T_10760_row1_col3" class="data row1 col3" >0.771653</td>
#       <td id="T_10760_row1_col4" class="data row1 col4" >0.180046</td>
#       <td id="T_10760_row1_col5" class="data row1 col5" >0.168063</td>
#       <td id="T_10760_row1_col6" class="data row1 col6" >0.026887</td>
#       <td id="T_10760_row1_col7" class="data row1 col7" >7234741</td>
#       <td id="T_10760_row1_col8" class="data row1 col8" >269080562</td>
#       <td id="T_10760_row1_col9" class="data row1 col9" >134518667</td>
#       <td id="T_10760_row1_col10" class="data row1 col10" >25395</td>
#     </tr>
#   </tbody>
# </table>

# %%
display_df_mono(render_csv("two_identical_smt.csv"))
# Out:
# <style type="text/css">
# #T_1b8b4_row0_col0, #T_1b8b4_row0_col1, #T_1b8b4_row0_col2, #T_1b8b4_row0_col3, #T_1b8b4_row0_col4, #T_1b8b4_row0_col5, #T_1b8b4_row0_col6, #T_1b8b4_row0_col7, #T_1b8b4_row0_col8, #T_1b8b4_row0_col9, #T_1b8b4_row0_col10, #T_1b8b4_row1_col0, #T_1b8b4_row1_col1, #T_1b8b4_row1_col2, #T_1b8b4_row1_col3, #T_1b8b4_row1_col4, #T_1b8b4_row1_col5, #T_1b8b4_row1_col6, #T_1b8b4_row1_col7, #T_1b8b4_row1_col8, #T_1b8b4_row1_col9, #T_1b8b4_row1_col10 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_1b8b4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b8b4_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_1b8b4_level0_col1" class="col_heading level0 col1" >IC</th>
#       <th id="T_1b8b4_level0_col2" class="col_heading level0 col2" >Cycles</th>
#       <th id="T_1b8b4_level0_col3" class="col_heading level0 col3" >CPI</th>
#       <th id="T_1b8b4_level0_col4" class="col_heading level0 col4" >CT</th>
#       <th id="T_1b8b4_level0_col5" class="col_heading level0 col5" >ET</th>
#       <th id="T_1b8b4_level0_col6" class="col_heading level0 col6" >L1_dcache_miss_rate</th>
#       <th id="T_1b8b4_level0_col7" class="col_heading level0 col7" >L1_dcache_misses</th>
#       <th id="T_1b8b4_level0_col8" class="col_heading level0 col8" >L1_dcache_accesses</th>
#       <th id="T_1b8b4_level0_col9" class="col_heading level0 col9" >branches</th>
#       <th id="T_1b8b4_level0_col10" class="col_heading level0 col10" >branch_misses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b8b4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1b8b4_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_1b8b4_row0_col1" class="data row0 col1" >1209672369</td>
#       <td id="T_1b8b4_row0_col2" class="data row0 col2" >848432357</td>
#       <td id="T_1b8b4_row0_col3" class="data row0 col3" >0.701374</td>
#       <td id="T_1b8b4_row0_col4" class="data row0 col4" >0.178996</td>
#       <td id="T_1b8b4_row0_col5" class="data row0 col5" >0.151866</td>
#       <td id="T_1b8b4_row0_col6" class="data row0 col6" >0.033193</td>
#       <td id="T_1b8b4_row0_col7" class="data row0 col7" >8930237</td>
#       <td id="T_1b8b4_row0_col8" class="data row0 col8" >269040253</td>
#       <td id="T_1b8b4_row0_col9" class="data row0 col9" >134532123</td>
#       <td id="T_1b8b4_row0_col10" class="data row0 col10" >17795</td>
#     </tr>
#     <tr>
#       <th id="T_1b8b4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1b8b4_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_1b8b4_row1_col1" class="data row1 col1" >1209864795</td>
#       <td id="T_1b8b4_row1_col2" class="data row1 col2" >772269633</td>
#       <td id="T_1b8b4_row1_col3" class="data row1 col3" >0.638311</td>
#       <td id="T_1b8b4_row1_col4" class="data row1 col4" >0.178972</td>
#       <td id="T_1b8b4_row1_col5" class="data row1 col5" >0.138215</td>
#       <td id="T_1b8b4_row1_col6" class="data row1 col6" >0.019591</td>
#       <td id="T_1b8b4_row1_col7" class="data row1 col7" >5271965</td>
#       <td id="T_1b8b4_row1_col8" class="data row1 col8" >269098005</td>
#       <td id="T_1b8b4_row1_col9" class="data row1 col9" >134568878</td>
#       <td id="T_1b8b4_row1_col10" class="data row1 col10" >18180</td>
#     </tr>
#   </tbody>
# </table>

# %%
## SMT vs CMP

# %%
! make -C popcounts clean popcount_D
! echo "IC,Cycles,CPI,CT,ET,L1_dcache_miss_rate,L1_dcache_misses,L1_dcache_accesses,branches,branch_misses" > stats.csv
! taskset -c 10 ./mv/matvec 16384 & taskset -c 0 ./popcounts/popcount_D
# Out:
# make: Entering directory '/nfshome/htseng/courses/CS203/demo/multiprocessor/popcounts'
# rm -f popcount_A popcount_B popcount_C popcount_D popcount_SSE42 popcount_E
# g++ -O3 -DHAVE_LINUX_PERF_EVENT_H -w -DD popcount.cpp perfstats.o -o popcount_D
# g++ -S -O3 -DHAVE_LINUX_PERF_EVENT_H -w -DD popcount.cpp -o D.s
# make: Leaving directory '/nfshome/htseng/courses/CS203/demo/multiprocessor/popcounts'
# 41845914.000000,41745652
# Result: 32000010811

# %%
#! cat stats.csv
display_df_mono(render_csv("stats.csv"))
# !cp stats.csv two_different_cmp.csv
# Out:
# <style type="text/css">
# #T_751b6_row0_col0, #T_751b6_row0_col1, #T_751b6_row0_col2, #T_751b6_row0_col3, #T_751b6_row0_col4, #T_751b6_row0_col5, #T_751b6_row0_col6, #T_751b6_row0_col7, #T_751b6_row0_col8, #T_751b6_row0_col9, #T_751b6_row0_col10, #T_751b6_row1_col0, #T_751b6_row1_col1, #T_751b6_row1_col2, #T_751b6_row1_col3, #T_751b6_row1_col4, #T_751b6_row1_col5, #T_751b6_row1_col6, #T_751b6_row1_col7, #T_751b6_row1_col8, #T_751b6_row1_col9, #T_751b6_row1_col10 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_751b6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_751b6_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_751b6_level0_col1" class="col_heading level0 col1" >IC</th>
#       <th id="T_751b6_level0_col2" class="col_heading level0 col2" >Cycles</th>
#       <th id="T_751b6_level0_col3" class="col_heading level0 col3" >CPI</th>
#       <th id="T_751b6_level0_col4" class="col_heading level0 col4" >CT</th>
#       <th id="T_751b6_level0_col5" class="col_heading level0 col5" >ET</th>
#       <th id="T_751b6_level0_col6" class="col_heading level0 col6" >L1_dcache_miss_rate</th>
#       <th id="T_751b6_level0_col7" class="col_heading level0 col7" >L1_dcache_misses</th>
#       <th id="T_751b6_level0_col8" class="col_heading level0 col8" >L1_dcache_accesses</th>
#       <th id="T_751b6_level0_col9" class="col_heading level0 col9" >branches</th>
#       <th id="T_751b6_level0_col10" class="col_heading level0 col10" >branch_misses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_751b6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_751b6_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_751b6_row0_col1" class="data row0 col1" >1209289948</td>
#       <td id="T_751b6_row0_col2" class="data row0 col2" >779882286</td>
#       <td id="T_751b6_row0_col3" class="data row0 col3" >0.644909</td>
#       <td id="T_751b6_row0_col4" class="data row0 col4" >0.179204</td>
#       <td id="T_751b6_row0_col5" class="data row0 col5" >0.139758</td>
#       <td id="T_751b6_row0_col6" class="data row0 col6" >0.019189</td>
#       <td id="T_751b6_row0_col7" class="data row0 col7" >5160475</td>
#       <td id="T_751b6_row0_col8" class="data row0 col8" >268928601</td>
#       <td id="T_751b6_row0_col9" class="data row0 col9" >134457681</td>
#       <td id="T_751b6_row0_col10" class="data row0 col10" >33797</td>
#     </tr>
#     <tr>
#       <th id="T_751b6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_751b6_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_751b6_row1_col1" class="data row1 col1" >80023910352</td>
#       <td id="T_751b6_row1_col2" class="data row1 col2" >19519405983</td>
#       <td id="T_751b6_row1_col3" class="data row1 col3" >0.243920</td>
#       <td id="T_751b6_row1_col4" class="data row1 col4" >0.182387</td>
#       <td id="T_751b6_row1_col5" class="data row1 col5" >3.560084</td>
#       <td id="T_751b6_row1_col6" class="data row1 col6" >0.000015</td>
#       <td id="T_751b6_row1_col7" class="data row1 col7" >298307</td>
#       <td id="T_751b6_row1_col8" class="data row1 col8" >20009287895</td>
#       <td id="T_751b6_row1_col9" class="data row1 col9" >15670</td>
#       <td id="T_751b6_row1_col10" class="data row1 col10" >1004033394</td>
#     </tr>
#   </tbody>
# </table>

# %%
display_df_mono(render_csv("two_different_smt.csv"))
# Out:
# <style type="text/css">
# #T_c6f7b_row0_col0, #T_c6f7b_row0_col1, #T_c6f7b_row0_col2, #T_c6f7b_row0_col3, #T_c6f7b_row0_col4, #T_c6f7b_row0_col5, #T_c6f7b_row0_col6, #T_c6f7b_row0_col7, #T_c6f7b_row0_col8, #T_c6f7b_row0_col9, #T_c6f7b_row0_col10, #T_c6f7b_row1_col0, #T_c6f7b_row1_col1, #T_c6f7b_row1_col2, #T_c6f7b_row1_col3, #T_c6f7b_row1_col4, #T_c6f7b_row1_col5, #T_c6f7b_row1_col6, #T_c6f7b_row1_col7, #T_c6f7b_row1_col8, #T_c6f7b_row1_col9, #T_c6f7b_row1_col10 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_c6f7b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6f7b_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_c6f7b_level0_col1" class="col_heading level0 col1" >IC</th>
#       <th id="T_c6f7b_level0_col2" class="col_heading level0 col2" >Cycles</th>
#       <th id="T_c6f7b_level0_col3" class="col_heading level0 col3" >CPI</th>
#       <th id="T_c6f7b_level0_col4" class="col_heading level0 col4" >CT</th>
#       <th id="T_c6f7b_level0_col5" class="col_heading level0 col5" >ET</th>
#       <th id="T_c6f7b_level0_col6" class="col_heading level0 col6" >L1_dcache_miss_rate</th>
#       <th id="T_c6f7b_level0_col7" class="col_heading level0 col7" >L1_dcache_misses</th>
#       <th id="T_c6f7b_level0_col8" class="col_heading level0 col8" >L1_dcache_accesses</th>
#       <th id="T_c6f7b_level0_col9" class="col_heading level0 col9" >branches</th>
#       <th id="T_c6f7b_level0_col10" class="col_heading level0 col10" >branch_misses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6f7b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c6f7b_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_c6f7b_row0_col1" class="data row0 col1" >1209378406</td>
#       <td id="T_c6f7b_row0_col2" class="data row0 col2" >820657355</td>
#       <td id="T_c6f7b_row0_col3" class="data row0 col3" >0.678578</td>
#       <td id="T_c6f7b_row0_col4" class="data row0 col4" >0.178992</td>
#       <td id="T_c6f7b_row0_col5" class="data row0 col5" >0.146891</td>
#       <td id="T_c6f7b_row0_col6" class="data row0 col6" >0.020265</td>
#       <td id="T_c6f7b_row0_col7" class="data row0 col7" >5449862</td>
#       <td id="T_c6f7b_row0_col8" class="data row0 col8" >268924620</td>
#       <td id="T_c6f7b_row0_col9" class="data row0 col9" >134483002</td>
#       <td id="T_c6f7b_row0_col10" class="data row0 col10" >17491</td>
#     </tr>
#     <tr>
#       <th id="T_c6f7b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c6f7b_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_c6f7b_row1_col1" class="data row1 col1" >80045046309</td>
#       <td id="T_c6f7b_row1_col2" class="data row1 col2" >24421006296</td>
#       <td id="T_c6f7b_row1_col3" class="data row1 col3" >0.305091</td>
#       <td id="T_c6f7b_row1_col4" class="data row1 col4" >0.179090</td>
#       <td id="T_c6f7b_row1_col5" class="data row1 col5" >4.373547</td>
#       <td id="T_c6f7b_row1_col6" class="data row1 col6" >0.000030</td>
#       <td id="T_c6f7b_row1_col7" class="data row1 col7" >598184</td>
#       <td id="T_c6f7b_row1_col8" class="data row1 col8" >20016845598</td>
#       <td id="T_c6f7b_row1_col9" class="data row1 col9" >33188</td>
#       <td id="T_c6f7b_row1_col10" class="data row1 col10" >1007770281</td>
#     </tr>
#   </tbody>
# </table>
