# %%
# %load_ext autoreload
# %autoreload 2
from notebook import *
# if get something about NUMEXPR_MAX_THREADS being set incorrectly, don't worry.  It's not a problem.
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
compare([do_render_code("arithmetics.c", show=["#ifdef A","else"]),do_render_code("arithmetics.c", show=["#else","endif"])])
# Out:
#             <style>
#         .side-by-side {
#             display: flex;
#             align-items: stretch;
#
#         }
#         .side-by-side-pane {
#             margin-right:1em;
#             border-right-style: solid;
#             border-right-color: black;
#             border-right-width: 1px;
#             flex: 1;
#         }
#         </style>
#         <div class="side-by-side"> <div class='side-by-side-pane'><style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .output_html .hll { background-color: #ffffcc }
# .output_html { background: #f8f8f8; }
# ...

# %%
! make clean; make arithmetics_A arithmetics_B
! echo "method,IC,Cycles,CPI,CT,ET,DcacheMissRate,DcacheMisses,DcacheAccesses,Sum,Time" > arithmetics.csv
! echo "Using MUL";for i in $(seq 1 10); do echo -n "A,">>arithmetics.csv;./arithmetics_A 131072 13 >>arithmetics.csv; done
! echo "Using shift";for i in $(seq 1 10); do echo -n "B,">>arithmetics.csv;./arithmetics_B >>arithmetics.csv; done
# Out:
# rm -f arithmetics arithmetics_A arithmetics_B linked_list flip_array swap *.s *~ arithmetics_2_A arithmetics_2
# cc -DA  -DHAVE_LINUX_PERF_EVENT_H -O0 perfstats.c arithmetics.c -o arithmetics_A
# cc -DA  -DHAVE_LINUX_PERF_EVENT_H -O0 -S arithmetics.c -o A.s
# cc -DB  -DHAVE_LINUX_PERF_EVENT_H -O0 perfstats.c arithmetics.c -o arithmetics_B
# cc -DB  -DHAVE_LINUX_PERF_EVENT_H -O0 -S arithmetics.c -o B.s
# Using MUL
# Using shift

# %%
display_df_mono(render_csv("arithmetics.csv",columns=["IC","Cycles","CPI","CT","ET"],average_by='method'))
# Out:
# <style type="text/css">
# #T_4f449_row0_col0, #T_4f449_row0_col1, #T_4f449_row0_col2, #T_4f449_row0_col3, #T_4f449_row0_col4, #T_4f449_row0_col5, #T_4f449_row1_col0, #T_4f449_row1_col1, #T_4f449_row1_col2, #T_4f449_row1_col3, #T_4f449_row1_col4, #T_4f449_row1_col5 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_4f449">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f449_level0_col0" class="col_heading level0 col0" >method</th>
#       <th id="T_4f449_level0_col1" class="col_heading level0 col1" >IC</th>
#       <th id="T_4f449_level0_col2" class="col_heading level0 col2" >Cycles</th>
#       <th id="T_4f449_level0_col3" class="col_heading level0 col3" >CPI</th>
#       <th id="T_4f449_level0_col4" class="col_heading level0 col4" >CT</th>
#       <th id="T_4f449_level0_col5" class="col_heading level0 col5" >ET</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
compare([do_render_code("A.s", show=[".L9:","jb	.L9"]),do_render_code("B.s", show=[".L9:","jb	.L9"])])
# Out:
#             <style>
#         .side-by-side {
#             display: flex;
#             align-items: stretch;
#
#         }
#         .side-by-side-pane {
#             margin-right:1em;
#             border-right-style: solid;
#             border-right-color: black;
#             border-right-width: 1px;
#             flex: 1;
#         }
#         </style>
#         <div class="side-by-side"> <div class='side-by-side-pane'><style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .output_html .hll { background-color: #ffffcc }
# .output_html { background: #f8f8f8; }
# ...

# %%
! make clean; make OPTS=-O3 arithmetics_A arithmetics_B
! echo "method,IC,Cycles,CPI,CT,ET,DcacheMissRate,DcacheMisses,DcacheAccesses,Sum,Time" > arithmetics_O3.csv
! echo "Using MUL";for i in $(seq 1 10); do echo -n "A,">>arithmetics_O3.csv;./arithmetics_A 131072 13 >>arithmetics_O3.csv; done
! echo "Using shift";for i in $(seq 1 10); do echo -n "B,">>arithmetics_O3.csv;./arithmetics_B >>arithmetics_O3.csv; done
# Out:
# rm -f arithmetics arithmetics_A arithmetics_B linked_list flip_array swap *.s *~ arithmetics_2_A arithmetics_2
# cc -DA  -DHAVE_LINUX_PERF_EVENT_H -O3 perfstats.c arithmetics.c -o arithmetics_A
# cc -DA  -DHAVE_LINUX_PERF_EVENT_H -O3 -S arithmetics.c -o A.s
# cc -DB  -DHAVE_LINUX_PERF_EVENT_H -O3 perfstats.c arithmetics.c -o arithmetics_B
# cc -DB  -DHAVE_LINUX_PERF_EVENT_H -O3 -S arithmetics.c -o B.s
# Using MUL
# Using shift

# %%
display_df_mono(render_csv("arithmetics_O3.csv",columns=["IC","Cycles","CPI","CT","ET"],average_by='method'))
# Out:
# <style type="text/css">
# #T_4f377_row0_col0, #T_4f377_row0_col1, #T_4f377_row0_col2, #T_4f377_row0_col3, #T_4f377_row0_col4, #T_4f377_row0_col5, #T_4f377_row1_col0, #T_4f377_row1_col1, #T_4f377_row1_col2, #T_4f377_row1_col3, #T_4f377_row1_col4, #T_4f377_row1_col5 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_4f377">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f377_level0_col0" class="col_heading level0 col0" >method</th>
#       <th id="T_4f377_level0_col1" class="col_heading level0 col1" >IC</th>
#       <th id="T_4f377_level0_col2" class="col_heading level0 col2" >Cycles</th>
#       <th id="T_4f377_level0_col3" class="col_heading level0 col3" >CPI</th>
#       <th id="T_4f377_level0_col4" class="col_heading level0 col4" >CT</th>
#       <th id="T_4f377_level0_col5" class="col_heading level0 col5" >ET</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
compare([do_render_code("A.s", show=[".L9:","jb	.L9"]),do_render_code("B.s", show=[".L8:","jne	.L8"])])
# Out:
#             <style>
#         .side-by-side {
#             display: flex;
#             align-items: stretch;
#
#         }
#         .side-by-side-pane {
#             margin-right:1em;
#             border-right-style: solid;
#             border-right-color: black;
#             border-right-width: 1px;
#             flex: 1;
#         }
#         </style>
#         <div class="side-by-side"> <div class='side-by-side-pane'><style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .output_html .hll { background-color: #ffffcc }
# .output_html { background: #f8f8f8; }
# ...
