# %%
# %load_ext autoreload
# %autoreload 2
from notebook import *
# if get something about NUMEXPR_MAX_THREADS being set incorrectly, don't worry.  It's not a problem.
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Linked List v.s. Array

# %%
compare([do_render_code("linked_list.c", show="sum_of_array"),do_render_code("linked_list.c", show="depth_of_list")])
# Out:
#             <style>
#         .side-by-side {
#             display: flex;
#             align-items: stretch;
#
#         }
#         .side-by-side-pane {
#             margin-right:1em;
#             border-right-style: solid;
#             border-right-color: black;
#             border-right-width: 1px;
#             flex: 1;
#         }
#         </style>
#         <div class="side-by-side"> <div class='side-by-side-pane'><style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .output_html .hll { background-color: #ffffcc }
# .output_html { background: #f8f8f8; }
# .output_html .c { color: #3D7B7B; font-style: italic } /* Comment */
# .output_html .err { border: 1px solid #FF0000 } /* Error */
# .output_html .k { color: #008000; font-weight: bold } /* Keyword */
# .output_html .o { color: #666666 } /* Operator */
# .output_html .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# .output_html .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# .output_html .cp { color: #9C6500 } /* Comment.Preproc */
# .output_html .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# .output_html .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# .output_html .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# .output_html .gd { color: #A00000 } /* Generic.Deleted */
# .output_html .ge { font-style: italic } /* Generic.Emph */
# .output_html .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .output_html .gr { color: #E40000 } /* Generic.Error */
# .output_html .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .output_html .gi { color: #008400 } /* Generic.Inserted */
# .output_html .go { color: #717171 } /* Generic.Output */
# .output_html .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .output_html .gs { font-weight: bold } /* Generic.Strong */
# .output_html .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .output_html .gt { color: #0044DD } /* Generic.Traceback */
# .output_html .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .output_html .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .output_html .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .output_html .kp { color: #008000 } /* Keyword.Pseudo */
# .output_html .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .output_html .kt { color: #B00040 } /* Keyword.Type */
# .output_html .m { color: #666666 } /* Literal.Number */
# .output_html .s { color: #BA2121 } /* Literal.String */
# .output_html .na { color: #687822 } /* Name.Attribute */
# .output_html .nb { color: #008000 } /* Name.Builtin */
# .output_html .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .output_html .no { color: #880000 } /* Name.Constant */
# .output_html .nd { color: #AA22FF } /* Name.Decorator */
# .output_html .ni { color: #717171; font-weight: bold } /* Name.Entity */
# .output_html .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# .output_html .nf { color: #0000FF } /* Name.Function */
# .output_html .nl { color: #767600 } /* Name.Label */
# .output_html .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .output_html .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .output_html .nv { color: #19177C } /* Name.Variable */
# .output_html .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .output_html .w { color: #bbbbbb } /* Text.Whitespace */
# .output_html .mb { color: #666666 } /* Literal.Number.Bin */
# .output_html .mf { color: #666666 } /* Literal.Number.Float */
# .output_html .mh { color: #666666 } /* Literal.Number.Hex */
# .output_html .mi { color: #666666 } /* Literal.Number.Integer */
# .output_html .mo { color: #666666 } /* Literal.Number.Oct */
# .output_html .sa { color: #BA2121 } /* Literal.String.Affix */
# .output_html .sb { color: #BA2121 } /* Literal.String.Backtick */
# .output_html .sc { color: #BA2121 } /* Literal.String.Char */
# .output_html .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .output_html .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .output_html .s2 { color: #BA2121 } /* Literal.String.Double */
# .output_html .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# .output_html .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .output_html .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# .output_html .sx { color: #008000 } /* Literal.String.Other */
# .output_html .sr { color: #A45A77 } /* Literal.String.Regex */
# .output_html .s1 { color: #BA2121 } /* Literal.String.Single */
# .output_html .ss { color: #19177C } /* Literal.String.Symbol */
# .output_html .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .output_html .fm { color: #0000FF } /* Name.Function.Magic */
# .output_html .vc { color: #19177C } /* Name.Variable.Class */
# .output_html .vg { color: #19177C } /* Name.Variable.Global */
# .output_html .vi { color: #19177C } /* Name.Variable.Instance */
# .output_html .vm { color: #19177C } /* Name.Variable.Magic */
# .output_html .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="c1">// linked_list.c:1-101 (101 lines)</span>
# <span class="cp">#define _GNU_SOURCE</span>
# <span class="cp">#include</span><span class="w"> </span><span class="cpf">&lt;stdio.h&gt;</span>
# <span class="cp">#include</span><span class="w"> </span><span class="cpf">&lt;stdlib.h&gt;</span>
# <span class="cp">#include</span><span class="w"> </span><span class="cpf">&lt;string.h&gt;</span>
# <span class="cp">#include</span><span class="w"> </span><span class="cpf">&lt;time.h&gt;</span>
# <span class="cp">#include</span><span class="w"> </span><span class="cpf">&quot;perfstats.h&quot;</span>
# <span class="cp">#include</span><span class="w"> </span><span class="cpf">&lt;sched.h&gt;</span>
# <span class="cp">#include</span><span class="w"> </span><span class="cpf">&lt;unistd.h&gt;</span>
# <span class="kt">cpu_set_t</span><span class="w">  </span><span class="n">mask</span><span class="p">;</span>
#
#
# <span class="k">struct</span><span class="w"> </span><span class="nc">node</span>
# <span class="p">{</span>
# <span class="w">    </span><span class="kt">int</span><span class="w"> </span><span class="n">value</span><span class="p">;</span>
# <span class="w">    </span><span class="kt">int</span><span class="w"> </span><span class="n">linked</span><span class="p">;</span>
# <span class="w">    </span><span class="k">struct</span><span class="w"> </span><span class="nc">node</span><span class="w"> </span><span class="o">*</span><span class="n">next</span><span class="p">;</span>
# <span class="p">};</span>
#
# <span class="kt">int</span><span class="w"> </span><span class="nf">depth_of_list</span><span class="p">(</span><span class="k">struct</span><span class="w"> </span><span class="nc">node</span><span class="w"> </span><span class="o">*</span><span class="n">start</span><span class="p">)</span>
# <span class="p">{</span>
# <span class="w">    </span><span class="kt">int</span><span class="w"> </span><span class="n">number_of_nodes</span><span class="w"> </span><span class="o">=</span><span class="w"> </span><span class="mi">0</span><span class="p">;</span>
# <span class="w">    </span><span class="kt">unsigned</span><span class="w"> </span><span class="kt">long</span><span class="w"> </span><span class="n">sum</span><span class="o">=</span><span class="mi">0</span><span class="p">;</span>
# <span class="w">    </span><span class="k">struct</span><span class="w"> </span><span class="nc">node</span><span class="w"> </span><span class="o">*</span><span class="n">node</span><span class="

# %%
! make clean; make linked_list
! echo "size,list,IC,Cycles,CPI,CT,ET,L1_dcache_miss_rate,L1_dcache_misses,L1_dcache_accesses,branches,branch_misses" > stats.csv
! echo -n "1024,list," >> stats.csv
! ./linked_list 512 1 100
! echo -n "1024,array," >> stats.csv
! ./linked_list 512 0 100
# Out:
# rm -f arithmetics arithmetics_A arithmetics_B linked_list flip_array swap linked_list.s
# cc -O3 -DHAVE_LINUX_PERF_EVENT_H perfstats.c  linked_list.c -o linked_list
# perfstats.c: In function ‘change_cpufrequnecy’:
# perfstats.c:115:11: warning: implicit declaration of function ‘sched_getcpu’; did you mean ‘SYS_getcpu’? [-Wimplicit-function-declaration]
#   115 |     cpu = sched_getcpu();
#       |           ^~~~~~~~~~~~
#       |           SYS_getcpu
# linked_list.c: In function ‘main’:
# linked_list.c:81:5: warning: implicit declaration of function ‘gettimeofday’ [-Wimplicit-function-declaration]
#    81 |     gettimeofday(&time_start, NULL);
#       |     ^~~~~~~~~~~~
# linked_list.c:94:22: warning: zero-length gnu_printf format string [-Wformat-zero-length]
#    94 |     sprintf(preamble,"");
#       |                      ^~
# depth: 512
# depth: 512

# %%
display_df_mono(render_csv("stats.csv"))
# Out:
# <style type="text/css">
# #T_2d521_row0_col0, #T_2d521_row0_col1, #T_2d521_row0_col2, #T_2d521_row0_col3, #T_2d521_row0_col4, #T_2d521_row0_col5, #T_2d521_row0_col6, #T_2d521_row0_col7, #T_2d521_row0_col8, #T_2d521_row0_col9, #T_2d521_row0_col10, #T_2d521_row0_col11, #T_2d521_row0_col12, #T_2d521_row1_col0, #T_2d521_row1_col1, #T_2d521_row1_col2, #T_2d521_row1_col3, #T_2d521_row1_col4, #T_2d521_row1_col5, #T_2d521_row1_col6, #T_2d521_row1_col7, #T_2d521_row1_col8, #T_2d521_row1_col9, #T_2d521_row1_col10, #T_2d521_row1_col11, #T_2d521_row1_col12 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_2d521">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d521_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_2d521_level0_col1" class="col_heading level0 col1" >size</th>
#       <th id="T_2d521_level0_col2" class="col_heading level0 col2" >list</th>
#       <th id="T_2d521_level0_col3" class="col_heading level0 col3" >IC</th>
#       <th id="T_2d521_level0_col4" class="col_heading level0 col4" >Cycles</th>
#       <th id="T_2d521_level0_col5" class="col_heading level0 col5" >CPI</th>
#       <th id="T_2d521_level0_col6" class="col_heading level0 col6" >CT</th>
#       <th id="T_2d521_level0_col7" class="col_heading level0 col7" >ET</th>
#       <th id="T_2d521_level0_col8" class="col_heading level0 col8" >L1_dcache_miss_rate</th>
#       <th id="T_2d521_level0_col9" class="col_heading level0 col9" >L1_dcache_misses</th>
#       <th id="T_2d521_level0_col10" class="col_heading level0 col10" >L1_dcache_accesses</th>
#       <th id="T_2d521_level0_col11" class="col_heading level0 col11" >branches</th>
#       <th id="T_2d521_level0_col12" class="col_heading level0 col12" >branch_misses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d521_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2d521_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_2d521_row0_col1" class="data row0 col1" >1024</td>
#       <td id="T_2d521_row0_col2" class="data row0 col2" >list</td>
#       <td id="T_2d521_row0_col3" class="data row0 col3" >217487</td>
#       <td id="T_2d521_row0_col4" class="data row0 col4" >269831</td>
#       <td id="T_2d521_row0_col5" class="data row0 col5" >1.240676</td>
#       <td id="T_2d521_row0_col6" class="data row0 col6" >0.189007</td>
#       <td id="T_2d521_row0_col7" class="data row0 col7" >0.000051</td>
#       <td id="T_2d521_row0_col8" class="data row0 col8" >0.002506</td>
#       <td id="T_2d521_row0_col9" class="data row0 col9" >141</td>
#       <td id="T_2d521_row0_col10" class="data row0 col10" >56273</td>
#       <td id="T_2d521_row0_col11" class="data row0 col11" >53459</td>
#       <td id="T_2d521_row0_col12" class="data row0 col12" >133</td>
#     </tr>
#     <tr>
#       <th id="T_2d521_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2d521_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_2d521_row1_col1" class="data row1 col1" >1024</td>
#       <td id="T_2d521_row1_col2" class="data row1 col2" >array</td>
#       <td id="T_2d521_row1_col3" class="data row1 col3" >257015</td>
#       <td id="T_2d521_row1_col4" class="data row1 col4" >62058</td>
#       <td id="T_2d521_row1_col5" class="data row1 col5" >0.241457</td>
#       <td id="T_2d521_row1_col6" class="data row1 col6" >0.177254</td>
#       <td id="T_2d521_row1_col7" class="data row1 col7" >0.000011</td>
#       <td id="T_2d521_row1_col8" class="data row1 col8" >0.001546</td>
#       <td id="T_2d521_row1_col9" class="data row1 col9" >87</td>
#       <td id="T_2d521_row1_col10" class="data row1 col10" >56278</td>
#       <td id="T_2d521_row1_col11" class="data row1 col11" >15360</td>
#       <td id="T_2d521_row1_col12" class="data row1 col12" >45</td>
#     </tr>
#   </tbody>
# </table>

# %%
render_code("linked_list.s", show=["sum_of_array:",".LFE40:"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 render_code("linked_list.s", show=["sum_of_array:",".LFE40:"])
#
# File ~/courses/CSE142/demo/pipeline/notebook.py:222, in render_code(*argc, **kwargs)
#     221 def render_code(*argc, **kwargs):
# --> 222     display(do_render_code(*argc, **kwargs))
#
# File ~/courses/CSE142/demo/pipeline/notebook.py:224, in do_render_code(file, lang, show, trim_ends)
#     223 def do_render_code(file, lang="c++", show=None, trim_ends=False):
# --> 224     lines = open(file).readlines()
#     225     start_line = 0
#     226     end_line = len(lines)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'linked_list.s'

# %% [markdown]
# The main loop between L10 and L9 has two
