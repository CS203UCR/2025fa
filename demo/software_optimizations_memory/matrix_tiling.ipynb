# %%
# Please execute/shift-return this cell everytime you run the notebook.  Don't edit it. 
# %load_ext autoreload
# %autoreload 2
from notebook import *
# Out:
# <style>h1 {font-size: 2vw;} h2 {font-size: 1.5vw;} p {font-size: 1.4vw;} div.prompt, code, output, prompt, kbd, pre, samp {font-family: 'SF Mono', 'Courier New', Courier, monospace, sans-serif !important;font-size: 1.4vw !important;}</style>

# %% [markdown]
# ## Case study: matrix multiplications
#
# GEMM that computes C = A $\times$ B is the core of many AI/ML applications. The most naive implementation of GEMM takes $O(n^3)$. Assume it takes 1 second to perform GEMM on 1,024$\times$1,024$\times$1,024 matrices. How much time do you expect it would take for 2,048$\times$2,048$\times$2,048 matrices?

# %%
render_code("matrix_mul/mm.c", show=["//START","//END"])
# Out:
# // matrix_mul/mm.c:54-75 (22 lines)
# //START
# void mm(double **a, double **b, double **c, uint64_t M, uint64_t N, uint64_t K)
# {
#   uint64_t i,j,k;
#   for(i = 0; i < M; i++)
#   {
#     for(j = 0; j < K; j++)
#     {
#       for(k = 0; k < N; k++)
#       {
#         c[i][j] += a[i][k]*b[k][j];
#         #ifdef DUMP
#           fprintf(stderr, "a[%ld][%ld], %p\n",i,k, &a[i][k]);
#           fprintf(stderr, "b[%ld][%ld], %p\n",k,j, &b[k][j]);
#           fprintf(stderr, "c[%ld][%ld], %p\n",i,j, &c[i][j]);
#         #endif
#       }
#     }
#   }
#   return;
# }
# //END

# %%
! cd matrix_mul; make clean; make mm
# Out:
# rm -f blockmm mm blockmm_transpose cachegrind.* mm_dump rect_blockmm_trans blockmm_transpose_reg blockmm_reg
# gcc -DHAVE_LINUX_PERF_EVENT_H -O3 mm.c perfstats.c -o mm

# %%
! cd matrix_mul; echo "IC,Cycles,CPI,CT_ns,ET_s,DL1_miss_rate,DL1_misses,DL1_accesses" > mm.csv
! ./matrix_mul/mm 512 >> ./matrix_mul/mm.csv ;./matrix_mul/mm 1024 >> ./matrix_mul/mm.csv ; ./matrix_mul/mm 2048 >> ./matrix_mul/mm.csv
#! cs203 job memory "./matrix_mul/mm 1024 >> ./matrix_mul/mm.csv ; ./matrix_mul/mm 2048 >> ./matrix_mul/mm.csv"
# Out:
# 234410496.000000,1406510080.000000,10521102336.000000,

# %%
display_df_mono(render_csv("matrix_mul/mm.csv"))
# Out:
# <style type="text/css">
# #T_6c2dd_row0_col0, #T_6c2dd_row0_col1, #T_6c2dd_row0_col2, #T_6c2dd_row0_col3, #T_6c2dd_row0_col4, #T_6c2dd_row0_col5, #T_6c2dd_row0_col6, #T_6c2dd_row0_col7, #T_6c2dd_row0_col8, #T_6c2dd_row1_col0, #T_6c2dd_row1_col1, #T_6c2dd_row1_col2, #T_6c2dd_row1_col3, #T_6c2dd_row1_col4, #T_6c2dd_row1_col5, #T_6c2dd_row1_col6, #T_6c2dd_row1_col7, #T_6c2dd_row1_col8, #T_6c2dd_row2_col0, #T_6c2dd_row2_col1, #T_6c2dd_row2_col2, #T_6c2dd_row2_col3, #T_6c2dd_row2_col4, #T_6c2dd_row2_col5, #T_6c2dd_row2_col6, #T_6c2dd_row2_col7, #T_6c2dd_row2_col8 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_6c2dd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c2dd_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_6c2dd_level0_col1" class="col_heading level0 col1" >IC</th>
#       <th id="T_6c2dd_level0_col2" class="col_heading level0 col2" >Cycles</th>
#       <th id="T_6c2dd_level0_col3" class="col_heading level0 col3" >CPI</th>
#       <th id="T_6c2dd_level0_col4" class="col_heading level0 col4" >CT_ns</th>
#       <th id="T_6c2dd_level0_col5" class="col_heading level0 col5" >ET_s</th>
#       <th id="T_6c2dd_level0_col6" class="col_heading level0 col6" >DL1_miss_rate</th>
#       <th id="T_6c2dd_level0_col7" class="col_heading level0 col7" >DL1_misses</th>
#       <th id="T_6c2dd_level0_col8" class="col_heading level0 col8" >DL1_accesses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c2dd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6c2dd_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_6c2dd_row0_col1" class="data row0 col1" >1070321949</td>
#       <td id="T_6c2dd_row0_col2" class="data row0 col2" >751077202</td>
#       <td id="T_6c2dd_row0_col3" class="data row0 col3" >0.701730</td>
#       <td id="T_6c2dd_row0_col4" class="data row0 col4" >0.194172</td>
#       <td id="T_6c2dd_row0_col5" class="data row0 col5" >0.145838</td>
#       <td id="T_6c2dd_row0_col6" class="data row0 col6" >0.241084</td>
#       <td id="T_6c2dd_row0_col7" class="data row0 col7" >128782783</td>
#       <td id="T_6c2dd_row0_col8" class="data row0 col8" >534182986</td>
#     </tr>
#     <tr>
#       <th id="T_6c2dd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6c2dd_row1_col0" class="data row1 col0" >1024</td>
#       <td id="T_6c2dd_row1_col1" class="data row1 col1" >8555235925</td>
#       <td id="T_6c2dd_row1_col2" class="data row1 col2" >10993339606</td>
#       <td id="T_6c2dd_row1_col3" class="data row1 col3" >1.284984</td>
#       <td id="T_6c2dd_row1_col4" class="data row1 col4" >0.194165</td>
#       <td id="T_6c2dd_row1_col5" class="data row1 col5" >2.134523</td>
#       <td id="T_6c2dd_row1_col6" class="data row1 col6" >0.232533</td>
#       <td id="T_6c2dd_row1_col7" class="data row1 col7" >993255401</td>
#       <td id="T_6c2dd_row1_col8" class="data row1 col8" >4271462935</td>
#     </tr>
#     <tr>
#       <th id="T_6c2dd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6c2dd_row2_col0" class="data row2 col0" >2048</td>
#       <td id="T_6c2dd_row2_col1" class="data row2 col1" >69061574396</td>
#       <td id="T_6c2dd_row2_col2" class="data row2 col2" >146587881797</td>
#       <td id="T_6c2dd_row2_col3" class="data row2 col3" >2.122568</td>
#       <td id="T_6c2dd_row2_col4" class="data row2 col4" >0.192867</td>
#       <td id="T_6c2dd_row2_col5" class="data row2 col5" >28.272007</td>
#       <td id="T_6c2dd_row2_col6" class="data row2 col6" >0.310036</td>
#       <td id="T_6c2dd_row2_col7" class="data row2 col7" >10689449462</td>
#       <td id="T_6c2dd_row2_col8" class="data row2 col8" >34478078500</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# WOW! Compuational complexty breaks again! The GEMM performance go wild because of cache misses!

# %% [markdown]
# What kind of misses are we seeing?

# %%
! make -C matrix_mul mm_dump; ./matrix_mul/mm_dump 256 >& mm_dump_address.csv
# Out:
# make: Entering directory '/nfshome/htseng/courses/CSE142/demo/software_optimizations_memory/matrix_mul'
# gcc -DHAVE_LINUX_PERF_EVENT_H -DDUMP -O3 mm.c perfstats.c -o mm_dump
# make: Leaving directory '/nfshome/htseng/courses/CSE142/demo/software_optimizations_memory/matrix_mul'

# %%
! echo "element,address" > mm_dump_addresses_digest.csv 
! head -n 101 mm_dump_address.csv | grep "b\[" >> mm_dump_addresses_digest.csv
df = pd.read_csv("mm_dump_addresses_digest.csv",skipfooter=1,engine='python')
df["address"] = df["address"].str.replace('0x','')
df["address"]=df[["address"]].apply(lambda x: x.astype(str).map(lambda x: int(x, base=16)))
# only show the first N addresses 
#N = 32
#df2 = df2.iloc[:N]
C = 49152
B = 64
A = 12
offset_bits = int(math.log2(B))
S = int(C/(B*A))
index_bits = int(math.log2(S))
df["tag"]=(df["address"].apply(lambda x: x >> (offset_bits+index_bits)))
df["tag"] = df["tag"].apply(lambda x: hex(x))
df["index"] = df["address"].apply(lambda x: hex((x>>offset_bits)%S))
df["address"] = df["address"].apply(lambda x: hex(x))
display_df_mono(df)
# Out:
# <style type="text/css">
# #T_d51d4_row0_col0, #T_d51d4_row0_col1, #T_d51d4_row0_col2, #T_d51d4_row0_col3, #T_d51d4_row1_col0, #T_d51d4_row1_col1, #T_d51d4_row1_col2, #T_d51d4_row1_col3, #T_d51d4_row2_col0, #T_d51d4_row2_col1, #T_d51d4_row2_col2, #T_d51d4_row2_col3, #T_d51d4_row3_col0, #T_d51d4_row3_col1, #T_d51d4_row3_col2, #T_d51d4_row3_col3, #T_d51d4_row4_col0, #T_
{
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_d51d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d51d4_level0_col0" class="col_heading level0 col0" >element</th>
#       <th id="T_d51d4_level0_col1" class="col_heading level0 col1" >address</th>
#       <th id="T_d51d4_level0_col2" class="col_heading level0 col2" >tag</th>
#       <th id="T_d51d4_level0_col3" class="col_heading level0 col3" >index</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d51d4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d51d4_row0_col0" class="data row0 col0" >b[0][0]</td>
#       <td id="T_d51d4_row0_col1" class="data row0 col1" >0x7d0a4b8d8000</td>
#       <td id="T_d51d4_row0_col2" class="data row0 col2" >0x7d0a4b8d8</td>
#       <td id="T_d51d4_row0_col3" class="data row0 col3" >0x0</td>
#     </tr>
#     <tr>
#       <th id="T_d51d4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d51d4_row1_col0" class="data row1 col0" >b[1][0]</td>
#       <td id="T_d51d4_row1_col1" class="data row1 col1" >0x7d0a4b8d8800</td>
#       <td id="T_d51d4_row1_col2" class="data row1 col2" >0x7d0a4b8d8</td>
#       <td id="T_d51d4_row1_col3" class="data row1 col3" >0x20</td>
#     </tr>
#     <tr>
#       <th id="T_d51d4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d51d4_row2_col0" class="data row2 col0" >b[2][0]</td>
#       <td id="T_d51d4_row2_col1" class="data row2 col1" >0x7d0a4b8d9000</td>
#       <td id="T_d51d4_row2_col2" class="data row2 col2" >0x7d0a4b8d9</td>
#       <td id="T_d51d4_row2_col3" class="data row2 col3" >0x0</td>
#     </tr>
#     <tr>
#       <th id="T_d51d4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d51d4_row3_col0" class="data row3 col0" >b[3][0]</td>
#       <td id="T_d51d4_row3_col1" class="data row3 col1" >0x7d0a4b8d9800</td>
#       <td id="T_d51d4_row3_col2" class="data row3 col2" >0x7d0a4b8d9</td>
#       <td id="T_d51d4_row3_col3" class="data row3 col3" >0x20</td>
#     </tr>
#     <tr>
#       <th id="T_d51d4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d51d4_row4_col0" class="data row4 col0" >b[4][0]</td>
#       <td id="T_d51d4_row4_col1" class="data row4 col1" >0x7d0a4b8da000</td>
#       <td id="T_d51d4_row4_col2" class="data row4 col2" >0x7d0a4b8da</td>
#       <td id="T_d51d4_row4_col3" class="data row4 col3" >0x0</td>
#     </tr>
#     <tr>
#       <th id="T_d51d4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d51d4_row5_col0" class="data row5 col0" >b[5][0]</td>
#       <td id="T_d51d4_row5_col1" class="data row5 col1" >0x7d0a4b8da800</td>
#       <td id="T_d51d4_row5_col2" class="data row5 col2" >0x7d0a4b8da</td>
#       <td id="T_d51d4_row5_col3" class="data row5 col3" >0x20</td>
#     </tr>
#     <tr>
#       <th id="T_d51d4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d51d4_row6_col0" class="data row6 col0" >b[6][0]</td>
#       <td id="T_d51d4_row6_col1" class="data row6 col1" >0x7d0a4b8db000</td>
#       <td id="T_d51d4_row6_col2" class="data row6 col2" >0x7d0a4b8db</td>
#       <td id="T_d51d4_row6_col3" class="data row6 col3" >0x0</td>
#     </tr>
#     <tr>
#       <th id="T_d51d4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d51d4_row7_col0" class="data row7 col0" >b[7][0]</td>
#       <td id="T_d51d4_row7_col1" class="data row7 col1" >0x7d0a4b8db800</td>
#       <td id="T_d51d4_row7_col2" class="data row7 col2" >0x7d0a4b8db</td>
#       <td id="T_d51d4_row7_col3" class="data row7 col3" >0x20</td>
#     </tr>
#     <tr>
#       <th id="T_d51d4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d51d4_row8_col0" class="data row8 col0" >b[8][0]</td>
#       <td id="T_d51d4_row8_col1" class="data row8 col1" >0x7d0a4b8dc000</td>
#       <td id="T_d51d4_row8_col2" class="data row8 col2" >0x7d0a4b8dc</td>
#       <td id="T_d51d4_row8_col3" class="data row8 col3" >0x0</td>
#     </tr>
#     <tr>
#       <th id="T_d51d4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d51d4_row9_col0" class="data row9 col0" >b[9][0]</td>
#       <td id="T_d51d4_row9_col1" class="data row9 col1" >0x7d0a4b8dc800</td>
#       <td id="T_d51d4_row9_col2" class="data row9 col2" >0x7d0a4b8dc</td>
#       <td id="T_d51d4_row9_col3" class="data row9 col3" >0x20</td>
#     </tr>
#     <tr>
#       <th id="T_d51d4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d51d4_row10_col0" class="data row10 col0" >b[10][0]</td>
#       <td id="T_d51d4_row10_col1" class="data row10 col1" >0x7d0a4b8dd000</td>
#       <td id="T_d51d4_row10_col2" class="data row10 col2" >0x7d0a4b8dd</td>
#       <td id="T_d51d4_row10_col3" class="data row10 col3" >0x0</td>
#     </tr>
#     <tr>
#       <th id="T_d51d4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d51d4_row11_col0" class="data row11 col0" >b[11][0]</td>
#       <td id="T_d51d4_row11_col1" class="data row11 col1" >0x7d0a4b8dd800</td>
#       <td id="T_d51d4_row11_col2" class="data row11 col2" >0x7d0a4b8dd</td>
#       <td id="T_d51d4_row11_col3" class="data row11 col3" >0x20</td>
#     </tr>
#     <tr>
#       <th id="T_d51d4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d51d4_row12_col0" class="data row12 col0" >b[12][0

# %% [markdown]
# ### Matrix tiling algorithm
#
# Let's try to partition GEMM into smaller tiles!

# %%
render_code("matrix_mul/blockmm.c", show=["//START","//END"])
# Out:
# // matrix_mul/blockmm.c:59-77 (19 lines)
# //START
# void blockmm(double **a, double **b, double **c, uint64_t M, uint64_t N, uint64_t K)
# {
#   uint64_t i,j,k, ii, jj, kk;
#   for(i = 0; i < M; i+=tile_size)
#   {
#     for(j = 0; j < K; j+=tile_size)
#     {
#       for(k = 0; k < N; k+=tile_size)
#       {
#           for(ii = i; ii < i+tile_size; ii++)
#             for(jj = j; jj < j+tile_size; jj++)
#               for(kk = k; kk < k+tile_size; kk++)
#                 c[ii][jj] += a[ii][kk]*b[kk][jj];
#       }
#     }
#   }
# }
# //END

# %%
! cd matrix_mul/; make clean blockmm
# Out:
# rm -f blockmm mm blockmm_transpose cachegrind.* mm_dump rect_blockmm_trans blockmm_transpose_reg blockmm_reg
# gcc -O4 -DHAVE_LINUX_PERF_EVENT_H blockmm.c perfstats.c -o blockmm
# blockmm.c: In function ‘main’:
# blockmm.c:48:16: warning: format ‘%lu’ expects argument of type ‘long unsigned int’, but argument 3 has type ‘int’ [-Wformat=]
#    48 |   printf("%d,%lu,",ARRAY_SIZE,tile_size);
#       |              ~~^              ~~~~~~~~~
#       |                |              |
#       |                |              int
#       |                long unsigned int
#       |              %u

# %% [markdown]
# ## Try with tile size == 32

# %%
! cd matrix_mul; echo "size,tile_size,IC,Cycles,CPI,CT_ns,ET_s,DL1_miss_rate,DL1_misses,DL1_accesses" > blockmm.csv
! ./matrix_mul/blockmm 512 32 >> ./matrix_mul/blockmm.csv ;./matrix_mul/blockmm 1024 32 >> ./matrix_mul/blockmm.csv ; ./matrix_mul/blockmm 2048 32 >> ./matrix_mul/blockmm.csv; ./matrix_mul/blockmm 4096 32 >> ./matrix_mul/blockmm.csv

# %%
display_df_mono(render_csv("matrix_mul/mm.csv"))
display_df_mono(render_csv("matrix_mul/blockmm.csv"))
# Out:
# <style type="text/css">
# #T_c307c_row0_col0, #T_c307c_row0_col1, #T_c307c_row0_col2, #T_c307c_row0_col3, #T_c307c_row0_col4, #T_c307c_row0_col5, #T_c307c_row0_col6, #T_c307c_row0_col7, #T_c307c_row0_col8, #T_c307c_row1_col0, #T_c307c_row1_col1, #T_c307c_row1_col2, #T_c307c_row1_col3, #T_c307c_row1_col4, #T_c307c_row1_col5, #T_c307c_row1_col6, #T_c307c_row1_col7, #T_c307c_row1_col8, #T_c307c_row2_col0, #T_c307c_row2_col1, #T_c307c_row2_col2, #T_c307c_row2_col3, #T_c307c_row2_col4, #T_c307c_row2_col5, #T_c307c_row2_col6, #T_c307c_row2_col7, #T_c307c_row2_col8 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_c307c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c307c_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_c307c_level0_col1" class="col_heading level0 col1" >IC</th>
#       <th id="T_c307c_level0_col2" class="col_heading level0 col2" >Cycles</th>
#       <th id="T_c307c_level0_col3" class="col_heading level0 col3" >CPI</th>
#       <th id="T_c307c_level0_col4" class="col_heading level0 col4" >CT_ns</th>
#       <th id="T_c307c_level0_col5" class="col_heading level0 col5" >ET_s</th>
#       <th id="T_c307c_level0_col6" class="col_heading level0 col6" >DL1_miss_rate</th>
#       <th id="T_c307c_level0_col7" class="col_heading level0 col7" >DL1_misses</th>
#       <th id="T_c307c_level0_col8" class="col_heading level0 col8" >DL1_accesses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c307c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c307c_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_c307c_row0_col1" class="data row0 col1" >1070321949</td>
#       <td id="T_c307c_row0_col2" class="data row0 col2" >751077202</td>
#       <td id="T_c307c_row0_col3" class="data row0 col3" >0.701730</td>
#       <td id="T_c307c_row0_col4" class="data row0 col4" >0.194172</td>
#       <td id="T_c307c_row0_col5" class="data row0 col5" >0.145838</td>
#       <td id="T_c307c_row0_col6" class="data row0 col6" >0.241084</td>
#       <td id="T_c307c_row0_col7" class="data row0 col7" >128782783</td>
#       <td id="T_c307c_row0_col8" class="data row0 col8" >534182986</td>
#     </tr>
#     <tr>
#       <th id="T_c307c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_
row1_col2" class="data row1 col2" >32</td>
#       <td id="T_44481_row1_col3" class="data row1 col3" >8926152193</td>
#       <td id="T_44481_row1_col4" class="data row1 col4" >3180589591</td>
#       <td id="T_44481_row1_col5" class="data row1 col5" >0.356323</td>
#       <td id="T_44481_row1_col6" class="data row1 col6" >0.193416</td>
#       <td id="T_44481_row1_col7" class="data row1 col7" >0.615178</td>
#       <td id="T_44481_row1_col8" class="data row1 col8" >0.208829</td>
#       <td id="T_44481_row1_col9" class="data row1 col9" >917512164</td>
#       <td id="T_44481_row1_col10" class="data row1 col10" >4393600541</td>
#     </tr>
#     <tr>
#       <th id="T_44481_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_44481_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_44481_row2_col1" class="data row2 col1" >2048</td>
#       <td id="T_44481_row2_col2" class="data row2 col2" >32</td>
#       <td id="T_44481_row2_col3" class="data row2 col3" >71543267861</td>
#       <td id="T_44481_row2_col4" class="data row2 col4" >27673229970</td>
#       <td id="T_44481_row2_col5" class="data row2 col5" >0.386804</td>
#       <td id="T_44481_row2_col6" class="data row2 col6" >0.192896</td>
#       <td id="T_44481_row2_col7" class="data row2 col7" >5.338042</td>
#       <td id="T_44481_row2_col8" class="data row2 col8" >0.217144</td>
#       <td id="T_44481_row2_col9" class="data row2 col9" >7646570957</td>
#       <td id="T_44481_row2_col10" class="data row2 col10" >35214279778</td>
#     </tr>
#     <tr>
#       <th id="T_44481_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_44481_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_44481_row3_col1" class="data row3 col1" >4096</td>
#       <td id="T_44481_row3_col2" class="data row3 col2" >32</td>
#       <td id="T_44481_row3_col3" class="data row3 col3" >572356014628</td>
#       <td id="T_44481_row3_col4" class="data row3 col4" >229734343523</td>
#       <td id="T_44481_row3_col5" class="data row3 col5" >0.401384</td>
#       <td id="T_44481_row3_col6" class="data row3 col6" >0.192857</td>
#       <td id="T_44481_row3_col7" class="data row3 col7" >44.305889</td>
#       <td id="T_44481_row3_col8" class="data row3 col8" >0.222482</td>
#       <td id="T_44481_row3_col9" class="data row3 col9" >62676954177</td>
#       <td id="T_44481_row3_col10" class="data row3 col10" >281717218738</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Try with tile size == 8

# %%
! cd matrix_mul; echo "size,tile_size,IC,Cycles,CPI,CT_ns,ET_s,DL1_miss_rate,DL1_misses,DL1_accesses" > blockmm.csv
! ./matrix_mul/blockmm 512 8 >> ./matrix_mul/blockmm.csv ;./matrix_mul/blockmm 1024 8 >> ./matrix_mul/blockmm.csv ; ./matrix_mul/blockmm 2048 8 >> ./matrix_mul/blockmm.csv; ./matrix_mul/blockmm 4096 8 >> ./matrix_mul/blockmm.csv

# %%
display_df_mono(render_csv("matrix_mul/mm.csv"))
display_df_mono(render_csv("matrix_mul/blockmm.csv"))
# Out:
# <style type="text/css">
# #T_e6e3c_row0_col0, #T_e6e3c_row0_col1, #T_e6e3c_row0_col2, #T_e6e3c_row0_col3, #T_e6e3c_row0_col4, #T_e6e3c_row0_col5, #T_e6e3c_row0_col6, #T_e6e3c_row0_col7, #T_e6e3c_row0_col8, #T_e6e3c_row1_col0, #T_e6e3c_row1_col1, #T_e6e3c_row1_col2, #T_e6e3c_row1_col3, #T_e6e3c_row1_col4, #T_e6e3c_row1_col5, #T_e6e3c_row1_col6, #T_e6e3c_row1_col7, #T_e6e3c_row1_col8, #T_e6e3c_row2_col0, #T_e6e3c_row2_col1, #T_e6e3c_row2_col2, #T_e6e3c_row2_col3, #T_e6e3c_row2_col4, #T_e6e3c_row2_col5, #T_e6e3c_row2_col6, #T_e6e3c_row2_col7, #T_e6e3c_row2_col8 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_e6e3c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6e3c_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_e6e3c_level0_col1" class="col_heading level0 col1" >IC</th>
#       <th id="T_e6e3c_level0_col2" class="col_heading level0 col2" >Cycles</th>
#       <th id="T_e6e3c_level0_col3" class="col_heading level0 col3" >CPI</th>
#       <th id="T_e6e3c_level0_col4" class="col_heading level0 col4" >CT_ns</th>
#       <th id="T_e6e3c_level0_col5" class="col_heading level0 col5" >ET_s</th>
#       <th id="T_e6e3c_level0_col6" class="col_heading level0 col6" >DL1_miss_rate</th>
#       <th id="T_e6e3c_level0_col7" class="col_heading level0 col7" >DL1_misses</th>
#       <th id="T_e6e3c_level0_col8" class="col_heading level0 col8" >DL1_accesses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6e3c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e6e3c_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_e6e3c_row0_col1" class="data row0 col1" >1070321949</td>
#       <td id="T_e6e3c_row0_col2" class="data row0 col2" >751077202</td>
#       <td id="T_e6e3c_row0_col3" class="data row0 col3" >0.701730</td>
#       <td id="T_e6e3c_row0_col4" class="data row0 col4" >0.194172</td>
#       <td id="T_e6e3c_row0_col5" class="data row0 col5" >0.145838</td>
#       <td id="T_e6e3c_row0_col6" class="data row0 col6" >0.241084</td>
#       <td id="T_e6e3c_row0_col7" class="data row0 col7" >128782783</td>
#       <td id="T_e6e3c_row0_col8" class="data row0 col8" >534182986</td>
#     </tr>
#     <tr>
#       <th id="T_e6e3c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e6e3c_row1_col0" class="data row1 col0" >1024</td>
#       <td id="T_e6e3c_row1_col1" class="data row1 col1" >8555235925</td>
#       <td id="T_e6e3c_row1_col2" class="data row1 col2" >10993339606</td>
#       <td id="T_e6e3c_row1_col3" class="data row1 col3" >1.284984</td>
#       <td id="T_e6e3c_row1_col4" class="data row1 col4" >0.194165</td>
#       <td id="T_e6e3c_row1_col5" class="data row1 col5" >2.134523</td>
#       <td id="T_e6e3c_row1_col6" class="data row1 col6" >0.232533</td>
#       <td id="T_e6e3c_row1_col7" class="data row1 col7" >993255401</td>
#       <td id="T_e6e3c_row1_col8" class="data row1 col8" >4271462935</td>
#     </tr>
#     <tr>
#       <th id="T_e6e3c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e6e3c_row2_col0" class="data row2 col0" >2048</td>
#       <td id="T_e6e3c_row2_col1" class="data row2 col1" >69061574396</td>
#       <td id="T_e6e3c_row2_col2" class="data row2 col2" >146587881797</td>
#       <td id="T_e6e3c_row2_col3" class="data row2 col3" >2.122568</td>
#       <td id="T_e6e3c_row2_col4" class="data row2 col4" >0.192867</td>
#       <td id="T_e6e3c_row2_col5" class="data row2 col5" >28.272007</td>
#       <td id="T_e6e3c_row2_col6" class="data row2 col6" >0.310036</td>
#       <td id="T_e6e3c_row2_col7" class="data row2 col7" >10689449462</td>
#       <td id="T_e6e3c_row2_col8" class="data row2 col8" >34478078500</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_8d7ab_row0_col0, #T_8d7ab_row0_col1, #T_8d7ab_row0_col2, #T_8d7ab_row0_col3, #T_8d7ab_row0_col4, #T_8d7ab_row0_col5, #T_8d7ab_row0_col6, #T_8d7ab_row0_col7, #T_8d7ab_row0_col8, #T_8d7ab_row0_col9, #T_8d7ab_row0_col10, #T_8d7ab_row1_col0, #T_8d7ab_row1_col1, #T_8d7ab_row1_col2, #T_8d7ab_row1_col3, #T_8d7ab_row1_col4, #T_8d7ab_row1_col5, #T_8d7ab_row1_col6, #T_8d7ab_row1_col7, #T_8d7ab_row1_col8, #T_8d7ab_row1_col9, #T_8d7ab_row1_col10, #T_8d7ab_row2_col0, #T_8d7ab_row2_col1, #T_8d7ab_row2_col2, #T_8d7ab_row2_col3, #T_8d7ab_row2_col4, #T_8d7ab_row2_col5, #T_8d7ab_row2_col6, #T_8d7ab_row2_col7, #T_8d7ab_row2_col8, #T_8d7ab_row2_col9, #T_8d7ab_row2_col10, #T_8d7ab_row3_col0, #T_8d7ab_row3_col1, #T_8d7ab_row3_col2, #T_8d7ab_row3_col3, #T_8d7ab_row3_col4, #T_8d7ab_row3_col5, #T_8d7ab_row3_col6, #T_8d7ab_row3_col7, #T_8d7ab_row3_col8, #T_8d7ab_row3_col9, #T_8d7ab_row3_col10 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T
d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_680bd_row5_col0" class="data row5 c

# %%
render_code("matrix_mul/blockmm_reg.c", show=["//START","//END"])
# Out:
# // matrix_mul/blockmm_reg.c:59-82 (24 lines)
# //START
# void blockmm(double **a, double **b, double **c, uint64_t M, uint64_t N, uint64_t K)
# {
#   uint64_t i,j,k, ii, jj, kk;
#     double result = 0;
#   for(i = 0; i < M; i+=tile_size)
#   {
#     for(j = 0; j < K; j+=tile_size)
#     {
#       for(k = 0; k < N; k+=tile_size)
#       {
#           for(ii = i; ii < i+tile_size; ii++)
#             for(jj = j; jj < j+tile_size; jj++)
#                 {
#                 result = 0;
#                 for(kk = k; kk < k+tile_size; kk++)
#                     result += a[ii][kk]*b[kk][jj];
#                 c[ii][jj] += result;
#           }
#       }
#     }
#   }
# }
# //END

# %%
! cd matrix_mul; make blockmm_reg; echo "size,tile_size,IC,Cycles,CPI,CT_ns,ET_s,DL1_miss_rate,DL1_misses,DL1_accesses" > blockmm_reg.csv
! ./matrix_mul/blockmm_reg 2048 4 >> ./matrix_mul/blockmm_reg.csv
! ./matrix_mul/blockmm_reg 2048 8 >> ./matrix_mul/blockmm_reg.csv
! ./matrix_mul/blockmm_reg 2048 16 >> ./matrix_mul/blockmm_reg.csv 
! ./matrix_mul/blockmm_reg 2048 32 >> ./matrix_mul/blockmm_reg.csv 
! ./matrix_mul/blockmm_reg 2048 64 >> ./matrix_mul/blockmm_reg.csv
! ./matrix_mul/blockmm_reg 2048 128 >> ./matrix_mul/blockmm_reg.csv 
! ./matrix_mul/blockmm_reg 2048 256 >> ./matrix_mul/blockmm_reg.csv 
! ./matrix_mul/blockmm_reg 2048 512 >> ./matrix_mul/blockmm_reg.csv 
display_df_mono(render_csv("matrix_mul/blockmm_reg.csv"))
# Out:
# gcc -O4 -DHAVE_LINUX_PERF_EVENT_H blockmm_reg.c perfstats.c -o blockmm_reg
# blockmm_reg.c: In function ‘main’:
# blockmm_reg.c:48:16: warning: format ‘%lu’ expects argument of type ‘long unsigned int’, but argument 3 has type ‘int’ [-Wformat=]
#    48 |   printf("%d,%lu,",ARRAY_SIZE,tile_size);
#       |              ~~^              ~~~~~~~~~
#       |                |              |
#       |                |              int
#       |                long unsigned int
#       |              %u
# <style type="text/css">
# #T_5d434_row0_col0, #T_5d434_row0_col1, #T_5d434_row0_col2, #T_5d434_row0_col3, #T_5d434_row0_col4, #T_5d434_row0_col5, #T_5d434_row0_col6, #T_5d434_row0_col7, #T_5d434_row0_col8, #T_5d434_row0_col9, #T_5d434_row0_col10, #T_5d434_row1_col0, #T_5d434_row1_col1, #T_5d434_row1_col2, #T_5d434_row1_col3, #T_5d434_row1_col4, #T_5d434_row1_col5, #T_5d434_row1_col6, #T_5d434_row1_col7, #T_5d434_row1_col8, #T_5d434_row1_col9, #T_5d434_row1_col10, #T_5d434_row2_col0, #T_5d434_row2_col1, #T_5d434_row2_col2, #T_5d434_row2_col3, #T_5d434_row2_col4, #T_5d434_row2_col5, #T_5d434_row2_col6, #T_5d434_row2_col7, #T_5d434_row2_col8, #T_5d434_row2_col9, #T_5d434_row2_col10, #T_5d434_row3_col0, #T_5d434_row3_col1, #T_5d434_row3_col2, #T_5d434_row3_col3, #T_5d434_row3_col4, #T_5d434_row3_col5, #T_5d434_row3_col6, #T_5d434_row3_col7, #T_5d434_row3_col8, #T_5d434_row3_col9, #T_5d434_row3_col10, #T_5d434_row4_col0, #T_5d434_row4_col1, #T_5d434_row4_col2, #T_5d434_row4_col3, #T_5d434_row4_col4, #T_5d434_row4_col5, #T_5d434_row4_col6, #T_5d434_row4_col7, #T_5d434_row4_col8, #T_5d434_row4_col9, #T_5d434_row4_col10, #T_5d434_row5_col0, #T_5d434_row5_col1, #T_5d434_row5_col2, #T_5d434_row5_col3, #T_5d434_row5_col4, #T_5d434_row5_col5, #T_5d434_row5_col6, #T_5d434_row5_col7, #T_5d434_row5_col8, #T_5d434_row5_col9, #T_5d434_row5_col10, #T_5d434_row6_col0, #T_5d434_row6_col1, #T_5d434_row6_col2, #T_5d434_row6_col3, #T_5d434_row6_col4, #T_5d434_row6_col5, #T_5d434_row6_col6, #T_5d434_row6_col7, #T_5d434_row6_col8, #T_5d434_row6_col9, #T_5d434_row6_col10, #T_5d434_row7_col0, #T_5d434_row7_col1, #T_5d434_row7_col2, #T_5d434_row7_col3, #T_5d434_row7_col4, #T_5d434_row7_col5, #T_5d434_row7_col6, #T_5d434_row7_col7, #T_5d434_row7_col8, #T_5d434_row7_col9, #T_5d434_row7_col10 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T
row4_col1" class="data row4 col1" >2048</td>
#       <td id="T_5d434_row4_col2" class="data row4 col2" >64</td>
#       <td id="T_5d434_row4_col3" class="data row4 col3" >58580600841</td>
#       <td id="T_5d434_row4_col4" class="data row4 col4" >20738095573</td>
#       <td id="T_5d434_row4_col5" class="data row4 col5" >0.354010</td>
#       <td id="T_5d434_row4_col6" class="data row4 col6" >0.192903</td>
#       <td id="T_5d434_row4_col7" class="data row4 col7" >4.000432</td>
#       <td id="T_5d434_row4_col8" class="data row4 col8" >0.378599</td>
#       <td id="T_5d434_row4_col9" class="data row4 col9" >8546354888</td>
#       <td id="T_5d434_row4_col10" class="data row4 col10" >22573608147</td>
#     </tr>
#     <tr>
#       <th id="T_5d434_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5d434_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_5d434_row5_col1" class="data row5 col1" >2048</td>
#       <td id="T_5d434_row5_col2" class="data row5 col2" >128</td>
#       <td id="T_5d434_row5_col3" class="data row5 col3" >57224706635</td>
#       <td id="T_5d434_row5_col4" class="data row5 col4" >20518268835</td>
#       <td id="T_5d434_row5_col5" class="data row5 col5" >0.358556</td>
#       <td id="T_5d434_row5_col6" class="data row5 col6" >0.192807</td>
#       <td id="T_5d434_row5_col7" class="data row5 col7" >3.956075</td>
#       <td id="T_5d434_row5_col8" class="data row5 col8" >0.394433</td>
#       <td id="T_5d434_row5_col9" class="data row5 col9" >8689345489</td>
#       <td

# %%
render_code("matrix_mul/blockmm_transpose.c", show=["//START","//END"])
# Out:
# // matrix_mul/blockmm_transpose.c:63-81 (19 lines)
# //START
# void blockmm_transpose(double **a, double **b, double **c, uint64_t M, uint64_t N, uint64_t K)
# {
#   int i,j,k, ii, jj, kk;
#   for(i = 0; i < M; i+=tile_size)
#   {
#     for(j = 0; j < K; j+=tile_size)
#     {
#       for(k = 0; k < N; k+=tile_size)
#       {
#           for(ii = i; ii < i+tile_size; ii++)
#             for(jj = j; jj < j+tile_size; jj++)
#               for(kk = k; kk < k+tile_size; kk++)
#                 c[ii][jj] += a[ii][kk]*b[jj][kk];
#       }
#     }
#   }
# }
# //END

# %% [markdown]
# ### Matrix transpose

# %%
! cd matrix_mul; rm blockmm_transpose; make blockmm_transpose; echo "size,tile_size,IC,Cycles,CPI,CT_ns,ET_s,DL1_miss_rate,DL1_misses,DL1_accesses" > blockmm_transpose.csv
! ./matrix_mul/blockmm_transpose 512 8 >> ./matrix_mul/blockmm_transpose.csv ;./matrix_mul/blockmm_transpose 1024 8 >> ./matrix_mul/blockmm_transpose.csv ; ./matrix_mul/blockmm_transpose 2048 8 >> ./matrix_mul/blockmm_transpose.csv; ./matrix_mul/blockmm_transpose 4096 8 >> ./matrix_mul/blockmm_transpose.csv
# Out:
# rm: cannot remove 'blockmm_transpose': No such file or directory
# gcc -O4 -DHAVE_LINUX_PERF_EVENT_H blockmm_transpose.c perfstats.c -o blockmm_transpose
# 234410496.000000,1406510080.000000,10521102336.000000,48070299648.000000,

# %%
! ./matrix_mul/blockmm_transpose 2048 8 >> ./matrix_mul/blockmm_transpose.csv 
! ./matrix_mul/blockmm_transpose 2048 16 >> ./matrix_mul/blockmm_transpose.csv 
! ./matrix_mul/blockmm_transpose 2048 32 >> ./matrix_mul/blockmm_transpose.csv 
! ./matrix_mul/blockmm_transpose 2048 64 >> ./matrix_mul/blockmm_transpose.csv
! ./matrix_mul/blockmm_transpose 2048 128 >> ./matrix_mul/blockmm_transpose.csv
! ./matrix_mul/blockmm_transpose 2048 256 >> ./matrix_mul/blockmm_transpose.csv
# Out:
# 10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,

# %%
display_df_mono(render_csv("matrix_mul/blockmm_transpose.csv"))
# Out:
# <style type="text/css">
# #T_fdf2d_row0_col0, #T_fdf2d_row0_col1, #T_fdf2d_row0_col2, #T_fdf2d_row0_col3, #T_fdf2d_row0_col4, #T_fdf2d_row0_col5, #T_fdf2d_row0_col6, #T_fdf2d_row0_col7, #T_fdf2d_row0_col8, #T_fdf2d_row0_col9, #T_fdf2d_row0_col10, #T_fdf2d_row1_col0, #T_fdf2d_row1_col1, #T_fdf2d_row1_col2, #T_fdf2d_row1_col3, #T_fdf2d_row1_col4, #T_fdf2d_row1_col5, #T_fdf2d_row1_col6, #T_fdf2d_row1_col7, #T_fdf2d_row1_col8, #T_fdf2d_row1_col9, #T_fdf2d_row1_col10, #T_fdf2d_row2_col0, #T_fdf2d_row2_col1, #T_fdf2d_row2_col2, #T_fdf2d_row2_col3, #T_fdf2d_row2_col4, #T_fdf2d_row2_col5, #T_fdf2d_row2_col6, #T_fdf2d_row2_col7, #T_fdf2d_row2_col8, #T_fdf2d_row2_col9, #T_fdf2d_
level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0e352_row5_col0" class="data row5 c

# %%
render_code("matrix_mul/blockmm_transpose_reg.c", show=["//START","//END"])
# Out:
# // matrix_mul/blockmm_transpose_reg.c:63-86 (24 lines)
# //START
# void blockmm_transpose(double **a, double **b, double **c, uint64_t M, uint64_t N, uint64_t K)
# {
#   int i,j,k, ii, jj, kk;
#   double result = 0;
#   for(i = 0; i < M; i+=tile_size)
#   {
#     for(j = 0; j < K; j+=tile_size)
#     {
#       for(k = 0; k < N; k+=tile_size)
#       {
#           for(ii = i; ii < i+tile_size; ii++)
#             for(jj = j; jj < j+tile_size; jj++)
#             {
#               result = 0;
#               for(kk = k; kk < k+tile_size; kk++)
#                 result += a[ii][kk]*b[jj][kk];
#               c[ii][jj] += result;
#             }
#       }
#     }
#   }
# }
# //END

# %%
! cd matrix_mul; rm blockmm_transpose_reg; make blockmm_transpose_reg; echo "size,tile_size,IC,Cycles,CPI,CT_ns,ET_s,DL1_miss_rate,DL1_misses,DL1_accesses" > blockmm_transpose_reg.csv 
! ./matrix_mul/blockmm_transpose_reg 2048 8 >> ./matrix_mul/blockmm_transpose_reg.csv 
! ./matrix_mul/blockmm_transpose_reg 2048 16 >> ./matrix_mul/blockmm_transpose_reg.csv 
! ./matrix_mul/blockmm_transpose_reg 2048 32 >> ./matrix_mul/blockmm_transpose_reg.csv 
! ./matrix_mul/blockmm_transpose_reg 2048 64 >> ./matrix_mul/blockmm_transpose_reg.csv
! ./matrix_mul/blockmm_transpose_reg 2048 128 >> ./matrix_mul/blockmm_transpose_reg.csv
! ./matrix_mul/blockmm_transpose_reg 2048 256 >> ./matrix_mul/blockmm_transpose_reg.csv
# Out:
# rm: cannot remove 'blockmm_transpose_reg': No such file or directory
# gcc -O4 -DHAVE_LINUX_PERF_EVENT_H blockmm_transpose_reg.c perfstats.c -o blockmm_transpose_reg
# 10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,

# %%
display_df_mono(render_csv("matrix_mul/blockmm_transpose_reg.csv"))
# Out:
# <style type="text/css">
# #T_a111f_row0_col0, #T_a111f_row0_col1, #T_a111f_row0_col2, #T_a111f_row0_col3, #T_a111f_row0_col4, #T_a111f_row0_col5, #T_a111f_row0_col6, #T_a111f_row0_col7, #T_a111f_row0_col8, #T_a111f_row0_col9, #T_a111f_row0_col10, #T_a111f_row1_col0, #T_a111f_row1_col1, #T_a111f_row1_col2, #T_a111f_row1_col3, #T_a111f_row1_col4, #T_a111f_row1_col5, #T_a111f_row1_col6, #T_a111f_row1_col7, #T_a111f_row1_col8, #T_a111f_row1_col9, #T_a111f_row1_col10, #T_a111f_row2_col0, #T_a111f_row2_col1, #T_a111f_row2_col2, #T_a111f_row2_col3, #T_a111f_row2_col4, #T_a111f_row2_col5, #T_a111f_row2_col6, #T_a111f_row2_col7, #T_a111f_row2_col8, #T_a111f_row2_col9, #T_a111f_row2_col10, #T_a111f_row3_col0, #T_a111f_row3_col1, #T_a111f_row3_col2, #T_a111f_row3_col3, #T_a111f_row3_col4, #T_a111f_row3_col5, #T_a111f_row3_col6, #T_a111f_row3_col7, #T_a111f_row3_col8, #T_a111f_row3_col9, #T_a111f_row3_col10, #T_a111f_row4_col0, #T_a111f_row4_col1, #T_a111f_row4_col2, #T_a111f_row4_col3, #T_a111f_row4_col4, #T_a111f_row4_col5, #T_a111f_row4_col6, #T_a111f_row4_col7, #T_a111f_row4_col8, #T_a111f_row4_col9, #T_a111f_row4_col10, #T_a111f_row5_col0, #T_a111f_row5_col1, #T_a111f_row5_col2, #T_a111f_row5_col3, #T_a111f_row5_col4, #T_a111f_row5_col5, #T_a111f_row5_col6, #T_a111f_row5_col7, #T_a111f_row5_col8, #T_a111f_row5_col9, #T_a111f_row5_col10 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_a111f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a111f_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_a111f_level0_col1" class="col_heading level0 col1" >size</th>
#       <th id="T_a111f_level0_col2" class="col_heading level0 col2" >tile_size</th>
#       <th id="T_a111f_level0_col3" class="col_heading level0 col3" >IC</th>
#       <th id="T_a111f_level0_col4" class="col_heading level0 col4" >Cycles</th>
#       <th id="T_a111f_level0_col5" class="col_heading level0 col5" >CPI</th>
#       <th id="T_a111f_level0_col6" class="col_heading level0 col6" >CT_ns</th>
#       <th id="T_a111f_level0_col7" class="col_heading level0 col7" >ET_s</th>
#       <th id="T_a111f_level0_col8" class="col_heading level0 col8" >DL1_miss_rate</th>
#       <th id="T_a111f_level0_col9" class="col_heading level0 col9" >DL1_misses</th>
#       <th id="T_a111f_level0_col10" class="col_heading level0 col10" >DL1_accesses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a111f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a111f_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_a111f_row0_col1" class="data row0 col1" >2048</td>
#       <td id="T_a111f_row0_col2" class="data row0 col2" >8</td>
#       <td id="T_a111f_row0_col3" class="data row0 col3" >60795754948</td>
#       <td id="T_a111f_row0_col4" class="data row0 col4" >16541443810</td>
#       <td id="T_a111f_row0_col5" class="data row0 col5" >0.272082</td>
#       <td id="T_a111f_row0_col6" class="data row0 col6" >0.192877</td>
#       <td id="T_a111f_row0_col7" class="data row0 col7" >3.190471</td>
#       <td id="T_a111f_row0_col8" class="data row0 col8" >0.012330</td>
#       <td id="T_a111f_row0_col9" class="data row0 col9" >195974777</td>
#       <td id="T_a111f_row0_col10" class="data row0 col10" >15894306863</td>
#     </tr>
#     <tr>
#       <th id="T_a111f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a111f_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_a111f_row1_col1" class="data row1 col1" >2048</td>
#       <td id="T_a111f_row1_col2" class="data row1 col2" >16</td>
#       <td id="T_a111f_row1_col3" class="data row1 col3" >49275921710</td>
#       <td id="T_a111f_row1_col4" class="data row1 col4" >10250946010</td>
#       <td id="T_a111f_row1_col5" class="data row1 col5" >0.208032</td>
#       <td id="T_a111f_row1_col6" class="data row1 col6" >0.192892</td>
#       <td id="T_a111f_row1_col7" class="data row1 col7" >1.977327</td>
#       <td id="T_a111f_row1_col8" class="data row1 col8" >0.063338</td>
#       <td id="T_a111f_row1_col9" class="data row1 col9" >761027406</td>
#       <td id="T_a111f_row1_col10" class="data row1 col10" >12015359435</td>
#     </tr>
#     <tr>
#       <th id="T_a111f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a111f_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_a111f_row2_col1" class="data row2 col1" >2048</td>
#       <td id="T_a111f_row2_col2" class="data row2 col2" >32</td>
#       <td id="T_a111f_row2_col3" class="data row2 col3" >43911382251</td>
#       <td id="T_a111f_row2_col4" class="data row2 col4" >9888353507</td>
#       <td id="T_a111f_row2_col5" class="data row2 col5" >0.225189</td>
#       <td id="T_a111f_row2_col6" class="data row2 col6" >0.192819</td>
#       <td id="T_a111f_row2_col7" class="data row2 col7" >1.906666</td>
#       <td id="T_a111f_row2_col8" class="data row2 col8" >0.104503</td>
#       <td id="T_a111f_row2_col9" class="data row2 col9" >1073524230</td>
#       <td id="T_a111f_row2_col10" class="data row2 col10" >10272694513</td>
#     </tr>
#     <tr>
#       <th id="T_a111f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a111f_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_a111f_row3_col1" class="data row3 col1" >2048</td>
#       <td id="T_a111f_row3_col2" class="data row3 col2" >64</td>
#       <td id="T_a111f_row3_col3" class="data row3 col3" >41303686372</td>
#       <td id="T_a111f_row3_col4" class="data row3 col4" >10143924208</td>
#       <td id="T_a111f_row3_col5" class="data row3 col5" >0.245594</td>
#       <td id="T_a111f_row3_col6" class="data row3 col6" >0.192821</td>
#       <td id="T_a111f_row3_col7" class="data row3 col7" >1.955957</td>
#       <td id="T_a111f_row3_col8" class="data row3 col8" >0.070866</td>
#       <td id="T_a111f_row3_col9" class="data row3 col9" >668872473</td>
#       <td id="T_a111f_row3_col10" class="data row3 col10" >9438541867</td>
#     </tr>
#     <tr>
#       <th id="T_a111f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a111f_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_a111f_row4_col1" class="data row4 col1" >2048</td>
#       <td id="T_a111f_row4_col2" class="data row4 col2" >128</td>
#       <td id="T_a111f_row4_col3" class="data row4 col3" >40017654922</td>
#       <td id="T_a111f_row4_col4" class="data row4 col4" >11954257904</td>
#       <td id="T_a111f_row4_col5" class="data row4 col5" >0.298725</td>
#       <td id="T_a111f_row4_col6" class="data row4 col6" >0.192826</td>
#       <td id="T_a111f_row4_col7" class="data row4 col7" >2.305091</td>
#       <td id="T_a111f_row4_col8" class="data row4 col8" >0.108819</td>
#       <td id="T_a111f_row4_col9" class="data row4 col9" >982633096</td>
#       <td id="T_a111f_row4_col10" class="data row4 col10" >9030013092</td>
#     </tr>
#     <tr>
#       <th id="T_a111f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a111f_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_a111f_row5_col1" class="data row5 col1" >2048</td>
#       <td id="T_a111f_row5_col2" class="data row5 col2" >256</td>
#       <td id="T_a111f_row5_col3" class="data row5 col3" >39382239439</td>
#       <td id="T_a111f_row5_col4" class="data row5 col4" >13815655204</td>
#       <td id="T_a111f_row5_col5" class="data row5 col5" >0.350809</td>
#       <td id="T_a111f_row5_col6" class="data row5 col6" >0.192924</td>
#       <td id="T_a111f_row5_col7" class="data row5 col7" >2.665376</td>
#       <td id="T_a111f_row5_col8" class="data row5 col8" >0.098270</td>
#       <td id="T_a111f_row5_col9" class="data row5 col9" >867637601</td>
#       <td id="T_a111f_row5_col10" class="data row5 col10" >8829113320</td>
#     </tr>
#   </tbody>
# </table>

# %%
render_code("matrix_mul/rect_blockmm_trans.c", show=["//START","//END"])
# Out:
# // matrix_mul/rect_blockmm_trans.c:73-96 (24 lines)
# //START
# void blockmm_transpose(double **a, double **b, double **c, uint64_t M, uint64_t N, uint64_t K)
# {
#   int i,j,k, ii, jj, kk;
#   double result=0;
#   for(i = 0; i < M; i+=tile_size_y)
#   {
#     for(j = 0; j < K; j+=tile_size_y)
#     {
#       for(k = 0; k < N; k+=tile_size_x)
#       {
#           for(ii = i; ii < i+tile_size_y; ii++)
#               for(jj = j; jj < j+tile_size_y; jj++)
#               {
#                       result = 0;
#                       for(kk = k; kk < k+tile_size_x ; kk++)
#                           result += a[ii][kk]*b[jj][kk];
#                       c[ii][jj] += result;
#               }
#       }
#     }
#   }
# }
# //END

# %%
! cd matrix_mul; make rect_blockmm_trans; echo "size,tile_size_x,tile_size_y,IC,Cycles,CPI,CT_ns,ET_s,DL1_miss_rate,DL1_misses,DL1_accesses" > rect_blockmm_trans.csv
! taskset -c 8 ./matrix_mul/rect_blockmm_trans 2048 8 8 >> ./matrix_mul/rect_blockmm_trans.csv 
! taskset -c 8 ./matrix_mul/rect_blockmm_trans 2048 8 16 >> ./matrix_mul/rect_blockmm_trans.csv 
! taskset -c 8 ./matrix_mul/rect_blockmm_trans 2048 16 8 >> ./matrix_mul/rect_blockmm_trans.csv
! taskset -c 8 ./matrix_mul/rect_blockmm_trans 2048 16 16 >> ./matrix_mul/rect_blockmm_trans.csv
! taskset -c 8 ./matrix_mul/rect_blockmm_trans 2048 32 8 >> ./matrix_mul/rect_blockmm_trans.csv 
! taskset -c 8 ./matrix_mul/rect_blockmm_trans 2048 32 16 >> ./matrix_mul/rect_blockmm_trans.csv 
! taskset -c 8 ./matrix_mul/rect_blockmm_trans 2048 64 8 >> ./matrix_mul/rect_blockmm_trans.csv
! taskset -c 8 ./matrix_mul/rect_blockmm_trans 2048 128 8 >> ./matrix_mul/rect_blockmm_trans.csv
! taskset -c 8 ./matrix_mul/rect_blockmm_trans 2048 256 8 >> ./matrix_mul/rect_blockmm_trans.csv
display_df_mono(render_csv("matrix_mul/rect_blockmm_trans.csv"))
# Out:
# gcc -O4 -DHAVE_LINUX_PERF_EVENT_H rect_blockmm_trans.c perfstats.c -o rect_blockmm_trans
# 10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,
# <style type="text/css">
# #T_a8f93_row0_col0, #T_a8f93_row0_col1, #T_a8f93_row0_col2, #T_a8f93_row0_col3, #T_a8f93_row0_col4, #T_a8f93_row0_col5, #T_a8f93_row0_col6, #T_a8f93_row0_col7, #T_a8f93_row0_col8, #T_a8f93_row0_col9, #T_a8f93_row0_col10, #T_a8f93_row0_col11, #T_a8f93_row1_col0, #T_a8f93_row1_col1, #T_a8f93_row1_col2, #T_a8f93_row1_col3, #T_a8f93_row1_col4, #T_a8f93_row1_col5, #T_a8f93_row1_col6, #T_a8f93_row1_col7, #T_a8f93_row1_col8, #T_a8f93_row1_col9, #T_a8f93_row1_col10, #T_a8f93_row1_col11, #T_a8f93_row2_col0, #T_a8f93_row2_col1, #T_a8f93_row2_col2, #T_a8f93_row2_col3, #T_a8f93_row2_col4, #T_a8f93_row2_col5, #T_a8f93_row2_col6, #T_a8f93_row2_col7, #T_a8f93_row2_col8, #T_a8f93_row2_col9, #T_a8f93_row2_col10, #T_a8f93_row2_col11, #T_a8f93_row3_col0, #T_a8f93_row3_col1, #T_a8f93_row3_col2, #T_a8f93_row3_col3, #T_a8f93_row3_col4, #T_a8f93_row3_col5, #T_a8f93_row3_col6, #T_a8f93_row3_col7, #T_a8f93_row3_col8, #T_a8f93_row3_col9, #T_a8f93_row3_col10, #T_a8f93_row3_col11, #T_a8f93_row4_col0, #T_a8f93_row4_col1, #T_a8f93_row4_col2, #T_a8f93_row4_col3, #T_a8f93_row4_col4, #T_a8f93_row4_col5, #T_a8f93_row4_col6, #T_a8f93_row4_col7, #T_a8f93_row4_col8, #T_a8f93_row4_col9, #T_a8f93_row4_col10, #T_a8f93_row4_col11, #T_a8f93_row5_col0, #T_a8f93_row5_col1, #T_a8f93_row5_col2, #T_a8f93_row5_col3, #T_a8f93_row5_col4, #T_a8f93_row5_col5, #T_a8f93_row5_col6, #T_a8f93_row5_col7, #T_a8f93_row5_col8, #T_a8f93_row5_col9, #T_a8f93_row5_col10, #T_a8f93_row5_col11, #T_a8f93_row6_col0, #T_a8f93_row6_col1, #T_a8f93_row6_col2, #T_a8f93_row6_col3, #T_a8f93_row6_col4, #T_a8f93_row6_col5, #T_a8f93_row6_col6, #T_a8f93_row6_col7, #T_a8f93_row6_col8, #T_a8f93_row6_col9, #T_a8f93_row6_col10, #T_a8f93_row6_col11, #T_a8f93_row7_col0, #T_a8f93_row7_col1, #T_a8f93_row7_col2, #T_a8f93_row7_col3, #T_a8f93_row7_col4, #T_a8f93_row7_col5, #T_a8f93_row7_col6, #T_a8f93_row7_col7, #T_a8f93_row7_col8, #T_a8f93_row7_col9, #T_a8f93_row7_col10, #T_a8f93_row7_col11, #T_a8f93_row8_col0, #T_a8f93_row8_col1, #T_a8f93_row8_col2, #T_a8f93_row8_col3, #T_a8f93_row8_col4, #T_a8f93_row8_col5, #T_a8f93_row8_col6, #T_a8f93_row8_col7, #T_a8f93_row8_col8, #T_a8f93_row8_col9, #T_a8f93_row8_col10, #T_a8f93_row8_col11 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_a8f93">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8f93_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_a8f93_level0_col1" class="col_heading level0 col1" >size</th>
#       <th id="T_a8f93_level0_col2" class="col_heading level0 col2" >tile_size_x</th>
#       <th id="T_a8f93_level0_col3" class="col_heading level0 col3" >tile_size_y</th>
#       <th id="T_a8f93_level0_col4" class="col_heading level0 col4" >IC</th>
#       <th id="T_a8f93_level0_col5" class="col_heading level0 col5" >Cycles</th>
#       <th id="T_a8f93_level0_col6" class="col_heading level0 col6" >CPI</th>
#       <th id="T_a8f93_level0_col7" class="col_heading level0 col7" >CT_ns</th>
#       <th id="T_a8f93_level0_col8" class="col_heading level0 col8" >ET_s</th>
#       <th id="T_a8f93_level0_col9" class="col_heading level0 col9" >DL1_miss_rate</th>
#       <th id="T_a8f93_level0_col10" class="col_heading level0 col10" >DL1_misses</th>
#       <th id="T_a8f93_level0_col11" class="col_heading level0 col11" >DL1_accesses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8f93_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8f93_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_a8f93_row0_col1" class="data row0 col1" >2048</td>
#       <td id="T_a8f93_row0_col2" class="data row0 col2" >8</td>
#       <td id="T_a8f93_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_a8f93_row0_col4" class="data row0 col4" >60695511235</td>
#       <td id="T_a8f93_row0_col5" class="data row0 col5" >11626279203</td>
#       <td id="T_a8f93_row0_col6" class="data row0 col6" >0.191551</td>
#       <td id="T_a8f93_row0_col7" class="data row0 col7" >0.192867</td>
#       <td id="T_a8f93_row0_col8" class="data row0 col8" >2.242328</td>
#       <td id="T_a8f93_row0_col9" class="data row0 col9" >0.004968</td>
#       <td id="T_a8f93_row0_col10" class="data row0 col10" >78651032</td>
#       <td id="T_a8f93_row0_col11" class="data row0 col11" >15831877513</td>
#     </tr>
#     <tr>
#       <th id="T_a8f93_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a8f93_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_a8f93_row1_col1" class="data row1 col1" >2048</td>
#       <td id="T_a8f93_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_a8f93_row1_col3" class="data row1 col3" >16</td>
#       <td id="T_a8f93_row1_col4" class="data row1 col4" >59756668949</td>
#       <td id="T_a8f93_row1_col5" class="data row1 col5" >12517922038</td>
#       <td id="T_a8f93_row1_col6" class="data row1 col6" >0.209482</td>
#       <td id="T_a8f93_row1_col7" class="data row1 col7" >0.192822</td>
#       <td id="T_a8f93_row1_col8" class="data row1 col8" >2.413731</td>
#       <td id="T_a8f93_row1_col9" class="data row1 col9" >0.021874</td>
#       <td id="T_a8f93_row1_col10" class="data row1 col10" >336312615</td>
#       <td id="T_a8f93_row1_col11" class="data row1 col11" >15374866920</td>
#     </tr>
#     <tr>
#       <th id="T_a8f93_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a8f93_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_a8f93_row2_col1" class="data row2 col1" >2048</td>
#       <td id="T_a8f93_row2_col2" class="data row2 col2" >16</td>
#       <td id="T_a8f93_row2_col3" class="data row2 col3" >8</td>
#       <td id="T_a8f93_row2_col4" class="data row2 col4" >49688080898</td>
#       <td id="T_a8f93_row2_col5" class="data row2 col5" >11540777138</td>
#       <td id="T_a8f93_row2_col6" class="data row2 col6" >0.232264</td>
#       <td id="T_a8f93_row2_col7" class="data row2 col7" >0.193273</td>
#       <td id="T_a8f93_row2_col8" class="data row2 col8" >2.230517</td>
#       <td id="T_a8f93_row2_col9" class="data row2 col9" >0.005338</td>
#       <td id="T_a8f93_row2_col10" class="data row2 col10" >65210663</td>
#       <td id="T_a8f93_row2_col11" class="data row2 col11" >12215976389</td>
#     </tr>
#     <tr>
#       <th id="T_a8f93_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a8f93_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_a8f93_row3_col1" class="data row3 col1" >2048</td>
#       <td id="T_a8f93_row3_col2" class="data row3 col2" >16</td>
#       <td id="T_a8f93_row3_col3" class="data row3 col3" >16</td>
#       <td id="T_a8f93_row3_col4" class="data row3 col4" >49214984050</td>
#       <td id="T_a8f93_row3_col5" class="data row3 col5" >9915479314</td>
#       <td id="T_a8f93_row3_col6" class="data row3 col6" >0.201473</td>
#       <td id="T_a8f93_row3_col7" class="data row3 col7" >0.193226</td>
#       <td id="T_a8f93_row3_col8" class="data row3 col8" >1.915931</td>
#       <td id="T_a8f93_row3_col9" class="data row3 col9" >0.051768</td>
#       <td id="T_a8f93_row3_col10" class="data row3 col10" >620489490</td>
#       <td id="T_a8f93_row3_col11" class="data row3 col11" >11985903158</td>
#     </tr>
#     <tr>
#       <th id="T_a8f93_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a8f93_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_a8f93_row4_col1" class="data row4 col1" >2048</td>
#       <td id="T_a8f93_row4_col2" class="data row4 col2" >32</td>
#       <td id="T_a8f93_row4_col3" class="data row4 col3" >8</td>
#       <td id="T_a8f93_row4_col4" class="data row4 col4" >44182602917</td>
#       <td id="T_a8f93_row4_col5" class="data row4 col5" >9832781983</td>
#       <td id="T_a8f93_row4_col6" class="data row4 col6" >0.222549</td>
#       <td id="T_a8f93_row4_col7" class="data row4 col7" >0.192903</td>
#       <td id="T_a8f93_row4_col8" class="data row4 col8" >1.896774</td>
#       <td id="T_a8f93_row4_col9" class="data row4 col9" >0.027039</td>
#       <td id="T_a8f93_row4_col10" class="data row4 col10" >281401039</td>
#       <td id="T_a8f93_row4_col11" class="data row4 col11" >

# %% [markdown]
# ## Prefetch
#
# x86 provide prefetch instructions. As a programmer, you may insert ```_mm_prefetch``` in x86 programs to perform software prefetch for your code. The gcc compiler also has a flag ```-fprefetch-loop-arrays``` to automatically insert software prefetch instructions.
#
# ### Using prefetch in matrix transpose code
#
# The following example is a highly optimized matrix transpose code. In the example, we try to prefetch the next row.

# %%
render_code("./prefetch/transpose.cpp", lang="c++", show=["//START", "//END"])
# Out:
# // ./prefetch/transpose.cpp:42-63 (22 lines)
#     //START
#     //  Iterate each row.
#     f_vector *y_iter = T;
#     do{
#         //  Iterate each column.
#         f_vector *ptr_x = y_iter + block;
#         f_vector *ptr_y = y_iter + row_size;
#
#         do{
#
# #ifdef ENABLE_PREFETCH
#             _mm_prefetch((char*)(ptr_y + row_size),_MM_HINT_T0);
# #endif
#             swap_block(ptr_x,ptr_y,block);
#
#             ptr_x += block;
#             ptr_y += row_size;
#         }while (ptr_y < stop_T);
#
#         y_iter += iter_size;
#     }while (y_iter < end);
#     //END

# %% [markdown]
# Now, let's take a look of what's happening!

# %%
! cd prefetch; make clean; make
# ! echo "Without prefetch -- the baseline"; ssh htseng@celebi "lscpu | grep Model; cd courses/CS203/demo/memory/prefetch/; ./transpose"
! echo "Without prefetch -- the baseline"
! lscpu | grep Model
! ./prefetch/transpose
! echo "With prefetch"
! ./prefetch/transpose_prefetch
# Out:
# rm -f blockmm_sse blockmm blockmm_sse_prefetch transpose transpose_prefetch
# g++ -msse4.1 -mavx -O3 transpose.cpp -o transpose
# g++ -msse4.1 -mavx -O3 -DENABLE_PREFETCH transpose.cpp -o transpose_prefetch
# Without prefetch -- the baseline
# Model name:                           13th Gen Intel(R) Core(TM) i7-13700F
# Model:                                183
# bytes = 1073741824
# Starting Data Transpose...   Done
# Time: 0.066379 seconds
# With prefetch
# bytes = 1073741824
# Starting Data Transpose...   Done
# Time: 0.079661 seconds

# %% [markdown]
# Let's try a different machine now.

# %%
! ssh htseng@xerneas "cd /nfshome/htseng/courses/CSE142/demo/software_optimizations_memory/; make -C ./prefetch clean; make -C ./prefetch ; lscpu | grep Model"
! echo "Without prefetch -- the baseline"; ssh htseng@xerneas  "/nfshome/htseng/courses/CSE142/demo/software_optimizations_memory/prefetch/transpose"
! echo "With prefetch";  ssh htseng@xerneas  "/nfshome/htseng/courses/CSE142/demo/software_optimizations_memory/prefetch/transpose_prefetch"
# Out:
# make: Entering directory '/nfshome/htseng/courses/CSE142/demo/software_optimizations_memory/prefetch'
# rm -f blockmm_sse blockmm blockmm_sse_prefetch transpose transpose_prefetch
# make: Leaving directory '/nfshome/htseng/courses/CSE142/demo/software_optimizations_memory/prefetch'
# make: Entering directory '/nfshome/htseng/courses/CSE142/demo/software_optimizations_memory/prefetch'
# g++ -msse4.1 -mavx -O3 transpose.cpp -o transpose
# g++ -msse4.1 -mavx -O3 -DENABLE_PREFETCH transpose.cpp -o transpose_prefetch
# make: Leaving directory '/nfshome/htseng/courses/CSE142/demo/software_optimizations_memory/prefetch'
# Model name:                           AMD Ryzen 9 5950X 16-Core Processor
# Model:                                33
# Without prefetch -- the baseline
# bytes = 1073741824
# Starting Data Transpose...   Done
# Time: 0.108898 seconds
# With prefetch
# bytes = 1073741824
# Starting Data Transpose...   Done
# Time: 0.102944 seconds

# %%
! ssh htseng@blissey "cd /nfshome/htseng/courses/CSE142/demo/memory/; make -C ./prefetch clean; make -C ./prefetch ; lscpu | grep Model"
! echo "Without prefetch -- the baseline"; ssh htseng@blissey  "/nfshome/htseng/courses/CSE142/demo/memory/prefetch/transpose"
! echo "With prefetch";  ssh htseng@blissey  "/nfshome/htseng/courses/CSE142/demo/memory/prefetch/transpose_prefetch"
# Out:
# make: *** prefetch: No such file or directory.  Stop.
# make: *** prefetch: No such file or directory.  Stop.
# Model name:                           AMD Ryzen 7 5700X 8-Core Processor
# Model:                                33
# Without prefetch -- the baseline
# bash: line 1: /nfshome/htseng/courses/CSE142/demo/memory/prefetch/transpose: No such file or directory
# With prefetch
# bash: line 1: /nfshome/htseng/courses/CSE142/demo/memory/prefetch/transpose_prefetch: No such file or directory

# %%
! ssh htseng@eevee "cd /nfshome/htseng/courses/CSE142/demo/memory/; make -C ./prefetch clean; make -C ./prefetch ; lscpu | grep Model"
! echo "Without prefetch -- the baseline"; ssh htseng@eevee  "/nfshome/htseng/courses/CSE142/demo/memory/prefetch/transpose"
! echo "With prefetch";  ssh htseng@eevee  "/nfshome/htseng/courses/CSE142/demo/memory/prefetch/transpose_prefetch"
# Out:
# make: *** prefetch: No such file or directory.  Stop.
# make: *** prefetch: No such file or directory.  Stop.
# Model:                                85
# Model name:                           Intel(R) Xeon(R) Gold 6140 CPU @ 2.30GHz
# Without prefetch -- the baseline
# bash: /nfshome/htseng/courses/CSE142/demo/memory/prefetch/transpose: No such file or directory
# With prefetch
# bash: /nfshome/htseng/courses/CSE142/demo/memory/prefetch/transpose_prefetch: No such file or directory

# %% [markdown]
# -- It doesn't work always!

# %%
render_code("matrix_mul/blockmm_interchange.c", show=["//START","//END"])
# Out:
# // matrix_mul/blockmm_interchange.c:59-77 (19 lines)
# //START
# void blockmm(double **a, double **b, double **c, uint64_t M, uint64_t N, uint64_t K)
# {
#   uint64_t i,j,k, ii, jj, kk;
#   for(i = 0; i < M; i+=tile_size)
#   {
#     for(j = 0; j < K; j+=tile_size)
#     {
#       for(k = 0; k < N; k+=tile_size)
#       {
#           for(kk = k; kk < k+tile_size; kk++)
#               for(ii = i; ii < i+tile_size; ii++)
#                 for(jj = j; jj < j+tile_size; jj++)
#                 c[ii][jj] += a[ii][kk]*b[kk][jj];
#       }
#     }
#   }
# }
# //END

# %%
! cd matrix_mul; rm -f blockmm_interchange; make blockmm_interchange; echo "size,tile_size,IC,Cycles,CPI,CT_ns,ET_s,DL1_miss_rate,DL1_misses,DL1_accesses" > blockmm_interchange.csv
! ./matrix_mul/blockmm_interchange 2048 8 >> ./matrix_mul/blockmm_interchange.csv 
! ./matrix_mul/blockmm_interchange 2048 16 >> ./matrix_mul/blockmm_interchange.csv 
! ./matrix_mul/blockmm_interchange 2048 32 >> ./matrix_mul/blockmm_interchange.csv 
! ./matrix_mul/blockmm_interchange 2048 64 >> ./matrix_mul/blockmm_interchange.csv
! ./matrix_mul/blockmm_interchange 2048 128 >> ./matrix_mul/blockmm_interchange.csv
! ./matrix_mul/blockmm_interchange 2048 256 >> ./matrix_mul/blockmm_interchange.csv
! cd matrix_mul; echo "size,tile_size,IC,Cycles,CPI,CT_ns,ET_s,DL1_miss_rate,DL1_misses,DL1_accesses" > blockmm.csv
! ./matrix_mul/blockmm 2048 16 >> ./matrix_mul/blockmm.csv 
! ./matrix_mul/blockmm 2048 32 >> ./matrix_mul/blockmm.csv 
! ./matrix_mul/blockmm 2048 64 >> ./matrix_mul/blockmm.csv
! ./matrix_mul/blockmm 2048 128 >> ./matrix_mul/blockmm.csv 
! ./matrix_mul/blockmm 2048 256 >> ./matrix_mul/blockmm.csv 
! ./matrix_mul/blockmm 2048 512 >> ./matrix_mul/blockmm.csv 
display_df_mono(render_csv("matrix_mul/blockmm.csv"))
display_df_mono(render_csv("matrix_mul/blockmm_interchange.csv"))
# Out:
# gcc -O4 -DHAVE_LINUX_PERF_EVENT_H blockmm_interchange.c perfstats.c -o blockmm_interchange
# blockmm_interchange.c: In function ‘main’:
# blockmm_interchange.c:48:16: warning: format ‘%lu’ expects argument of type ‘long unsigned int’, but argument 3 has type ‘int’ [-Wformat=]
#    48 |   printf("%d,%lu,",ARRAY_SIZE,tile_size);
#       |              ~~^              ~~~~~~~~~
#       |                |              |
#       |                |              int
#       |                long unsigned int
#       |              %u
# 10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,
# <style type="text/css">
# #T_a1e05_row0_col0, #T_a1e05_row0_col1, #T_a1e05_row0_col2, #T_a1e05_row0_col3, #T_a1e05_row0_col4, #T_a1e05_row0_col5, #T_a1e05_row0_col6, #T_a1e05_row0_col7, #T_a1e05_row0_col8, #T_a1e05_row0_col9, #T_a1e05_row0_col10, #T_a1e05_row1_col0, #T_a1e05_row1_col1, #T_a1e05_row1_col2, #T_a1e05_row1_col3, #T_a1e05_row1_col4, #T_a1e05_row1_col5, #T_a1e05_row1_col6, #T_a1e05_row1_col7, #T_a1e05_row1_col8, #T_a1e05_row1_col9, #T_a1e05_row1_col10, #T_a1e05_row2_col0, #T_a1e05_row2_col1, #T_a1e05_row2_col2, #T_a1e05_row2_col3, #T_a1e05_row2_col4, #T_a1e05_row2_col5, #T_a1e05_row2_col6, #T_a1e05_row2_col7, #T_a1e05_row2_col8, #T_a1e05_row2_col9, #T_a1e05_row2_col10, #T_a1e05_row3_col0, #T_a1e05_row3_col1, #T_a1e05_row3_col2, #T_a1e05_row3_col3, #T_a1e05_row3_col4, #T_a1e05_row3_col5, #T_a1e05_row3_col6, #T_a1e05_row3_col7, #T_a1e05_row3_col8, #T_a1e05_row3_col9, #T_a1e05_row3_col10, #T_a1e05_row4_col0, #T_a1e05_row4_col1, #T_a1e05_row4_col2, #T_a1e05_row4_col3, #T_a1e05_row4_col4, #T_a1e05_row4_col5, #T_a1e05_row4_col6, #T_a1e05_row4_col7, #T_a1e05_row4_col8, #T_a1e05_row4_col9, #T_a1e05_row4_col10, #T_a1e05_row5_col0, #T_a1e05_row5_col1, #T_a1e05_row5_col2, #T_a1e05_row5_col3, #T_a1e05_row5_col4, #T_a1e05_row5_col5, #T_a1e05_row5_col6, #T_a1e05_row5_col7, #T_a1e05_row5_col8, #T_a1e05_row5_col9, #T_a1e05_row5_col10 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_a1e05">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1e05_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_a1e05_level0_col1" class="col_heading level0 col1" >size</th>
#       <th id="T_a1e05_level0_col2" class="col_heading level0 col2" >tile_size</th>
#       <th id="T_a1e05_level0_col3" class="col_heading level0 col3" >IC</th>
#       <th id="T_a1e05_level0_col4" class="col_heading level0 col4" >Cycles</th>
#       <th id="T_a1e05_level0_col5" class="col_heading level0 col5" >CPI</th>
#       <th id="T_a1e05_level0_col6" class="col_heading level0 col6" >CT_ns</th>
#       <th id="T_a1e05_level0_col7" class="col_heading level0 col7" >ET_s</th>
#       <th id="T_a1e05_level0_col8" class="col_heading level0 col8" >DL1_miss_rate</th>
#       <th id="T_a1e05_level0_col9" class="col_heading level0 col9" >DL1_misses</th>
#       <th id="T_a1e05_level0_col10" class="col_heading level0 col10" >DL1_accesses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1e05_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a1e05_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_a1e05_row0_col1" class="data row0 col1" >2048</td>
#       <td id="T_a1e05_row0_col2" class="data row0 col2" >16</td>
#       <td id="T_a1e05_row0_col3" class="data row0 col3" >74472076034</td>
#       <td id="T_a1e05_row0_col4" class="data row0 col4" >19024335305</td>
#       <td id="T_a1e05_row0_col5" class="data row0 col5" >0.255456</td>
#       <td id="T_a1e05_row0_col6" class="data row0 col6" >0.192852</td>
#       <td id="T_a1e05_row0_col7" class="data row0 col7" >3.668886</td>
#       <td id="T_a1e05_row0_col8" class="data row0 col8" >0.071660</td>
#       <td id="T_a1e05_row0_col9" class="data row0 col9" >2587273712</td>
#       <td id="T_a1e05_row0_col10" class="data row0 col10" >36104629405</td>
#     </tr>
#     <tr>
#       <th id="T_a1e05_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a1e05_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_a1e05_row1_col1" class="data row1 col1" >2048</td>
#       <td id="T_a1e05_row1_col2" class="data row1 col2" >32</td>
#       <td id="T_a1e05_row1_col3" class="data row1 col3" >71543264238</td>
#       <td id="T_a1e05_row1_col4" class="data row1 col4" >27683303744</td>
#       <td id="T_a1e05_row1_col5" class="data row1 col5" >0.386945</td>
#       <td id="T_a1e05_row1_col6" class="data row1 col6" >0.192878</td>
#       <td id="T_a1e05_row1_col7" class="data row1 col7" >5.339509</td>
#       <td id="T_a1e05_row1_col8" class="data row1 col8" >0.217548</td>
#       <td id="T_a1e05_row1_col9" class="data row1 col9" >7660788748</td>
#       <td id="T_a1e05_row1_col10" class="data row1 col10" >35214298332</td>
#     </tr>
#     <tr>
#       <th id="T_a1e05_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a